# %%
# !pip install imbalanced-learn --user
# !pip install delayed

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Reading
#
# First we load the dataset, and check for any nulls.

# %%
df = pd.read_csv('../data/olist_order_reviews_dataset.csv')

# %%
df.head()
# Out:
#                           review_id                          order_id  \
# 0  7bc2406110b926393aa56f80a40eba40  73fc7af87114b39712e6da79b0a377eb
# 1  80e641a11e56f04c1ad469d5645fdfde  a548910a1c6147796b98fdf73dbeba33
# 2  228ce5500dc1d8e020d8d1322874b6f0  f9e4b658b201a9f2ecdecbb34bed034b
# 3  e64fb393e7b32834bb789ff8bb30750e  658677c97b385a9be170737859d3511b
# 4  f7c4243c7fe1938f181bec41a392bdeb  8e6bfb81e283fa7e4f11123a3fb894f1
#
#    review_score review_comment_title  \
# 0             4                  NaN
# 1             5                  NaN
# 2             5                  NaN
# 3             5                  NaN
# 4             5                  NaN
#
#                               review_comment_message review_creation_date  \
# 0                                                NaN  2018-01-18 00:00:00
# 1                                                NaN  2018-03-10 00:00:00
# 2                                                NaN  2018-02-17 00:00:00
# 3              Recebi bem antes do prazo estipulado.  2017-04-21 00:00:00
# 4  Parabéns lojas lannister adorei comprar pela I...  2018-03-01 00:00:00
#
#   review_answer_timestamp
# 0     2018-01-18 21:46:59
# 1     2018-03-11 03:05:13
# 2     2018-02-18 14:36:24
# 3     2017-04-21 22:02:06
# 4     2018-03-02 10:26:53

# %%
df.dtypes
# Out:
# review_id                  object
# order_id                   object
# review_score                int64
# review_comment_title       object
# review_comment_message     object
# review_creation_date       object
# review_answer_timestamp    object
# dtype: object

# %%
df.isnull().sum()
# Out:
# review_id                      0
# order_id                       0
# review_score                   0
# review_comment_title       88285
# review_comment_message     58247
# review_creation_date           0
# review_answer_timestamp        0
# dtype: int64

# %%
df.isnull().count()
# Out:
# review_id                  100000
# order_id                   100000
# review_score               100000
# review_comment_title       100000
# review_comment_message     100000
# review_creation_date       100000
# review_answer_timestamp    100000
# dtype: int64

# %%
df.nunique()
# Out:
# review_id                  99173
# order_id                   99441
# review_score                   5
# review_comment_title        4600
# review_comment_message     36921
# review_creation_date         637
# review_answer_timestamp    99010
# dtype: int64

# %% [markdown]
# # Using Reviews to Predict Score
#
# Problem: Given the review text, try and predict what the user rated for the product.
#
# We will use the text from
# 1. `review_comment_title`
# 2. `review_comment_message`
#
# To predict `review_score`
#
# We will not take into account any entry that does not have at least 1 of the columns mentioned above
#
# Methods:
# - Naive Bayes
# - Logistic Regression
# - LSTM

# %%
df = df[~df['review_comment_message'].isnull() | ~df['review_comment_title'].isnull()]

# %%
df = df[['review_comment_title', 'review_comment_message', 'review_score']].reset_index(drop=True)

# %%
df = df.fillna('')
df['review'] = df['review_comment_title'] + ' ' + df['review_comment_message']
df['review'] = df['review'].str.strip()
df['length'] = df['review'].str.len()

# %%
df.head()
# Out:
#   review_comment_title                             review_comment_message  \
# 0                                   Recebi bem antes do prazo estipulado.
# 1                       Parabéns lojas lannister adorei comprar pela I...
# 2            recomendo  aparelho eficiente. no site a marca do aparelh...
# 3                         Mas um pouco ,travando...pelo valor ta Boa.\r\n
# 4      Super recomendo  Vendedor confiável, produto ok e entrega antes...
#
#    review_score                                             review  length
# 0             5              Recebi bem antes do prazo estipulado.      37
# 1             5  Parabéns lojas lannister adorei comprar pela I...     100
# 2             4  recomendo aparelho eficiente. no site a marca ...     184
# 3             4        Mas um pouco ,travando...pelo valor ta Boa.      43
# 4             5  Super recomendo Vendedor confiável, produto ok...      72

# %% [markdown]
# # Analysis

# %%
print(df['review_score'].describe())
sns.countplot(x="review_score", data=df)
plt.show()
sns.boxplot(x="review_score", data=df)
# Out:
# count    43482.000000
# mean         3.674417
# std          1.614854
# min          1.000000
# 25%          2.000000
# 50%          5.000000
# 75%          5.000000
# max          5.000000
# Name: review_score, dtype: float64
# <AxesSubplot:xlabel='review_score'>

# %% [markdown]
# # Review Score
# The review score ranged from 1-5, with a mean of 3.67, and most of the reviews being a 5

# %%
print(df['length'].describe())
sns.boxplot(x="length", data=df)
# Out:
# count    43482.000000
# mean        70.435606
# std         55.871351
# min          0.000000
# 25%         28.000000
# 50%         55.000000
# 75%         98.000000
# max        229.000000
# Name: length, dtype: float64
# <AxesSubplot:xlabel='length'>

# %% [markdown]
# # Review
# Each review is 0-229 characters long, with an average of roughly 70 characters. About a sentence

# %%
from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

# Generate wordcloud
def generateWordCloud(text):
    wordcloud = WordCloud().generate(text)

    # Show wordcloud
    plt.imshow(wordcloud, interpolation='bilinear')
    plt.axis("off")
    plt.show()
    
generateWordCloud(" ".join(review for review in df['review']))

# %%
generateWordCloud(" ".join(review for review in df[df['review_score'] > 3]['review']))

# %% [markdown]
# - antes prazo: before deadline
# - produto chegou: product arrived
# - super recomendo: super recommended
# - chegou ante: arrived before
# - dentro prazo: within term
# - muito bom: very good

# %%
generateWordCloud(" ".join(review for review in df[df['review_score'] < 3]['review']))

# %% [markdown]
# - não recebi: not received
# - produto não: no product
# - não recomendo: not recommended
# - ainda não: not yet
# - foi entregue: was delivered
# - não foi: it was not

# %% [markdown]
# # Pre-processing of Text
#
# 1. We combine the review title and review together
# 2. We remove any review less than 10 characters long. Single word reviews are not very helpful
# 2. We remove any punctuation, newlines, excess whitespace, stopwords, numbers
# 3. Stem the words
#
# https://towardsdatascience.com/review-rating-prediction-a-combined-approach-538c617c495c
#
# https://medium.com/@datamonsters/text-preprocessing-in-python-steps-tools-and-examples-bf025f872908
#
# https://www.digitalocean.com/community/tutorials/how-to-perform-sentiment-analysis-in-python-3-using-the-natural-language-toolkit-nltk
#
# https://towardsdatascience.com/a-beginners-guide-to-sentiment-analysis-in-python-95e354ea84f6

# %% [markdown]
# [TFIDF Information](https://machinelearningmastery.com/prepare-text-data-machine-learning-scikit-learn/)
#
# We will use TF-IDF (Term Frequency–Inverse Document Frequency) to encode the sentences
# - Term Frequency: This summarizes how often a given word appears within a document.
# - Inverse Document Frequency: This downscales words that appear a lot across documents.

# %%
# Remove stopwords
import nltk
import string
from nltk.corpus import stopwords
from nltk.stem import RSLPStemmer # Portuguese stemmer

nltk.download('stopwords')
nltk.download('rslp')
portuguese_stopwords = stopwords.words('portuguese')
stemmer = nltk.stem.RSLPStemmer()

def process_text(text):
    text = ''.join([c for c in text if c not in string.punctuation]) # Remove punctuation
    text = ''.join([c for c in text if not c.isdigit()]) # Remove numbers
    text = text.lower().strip() # Lowercase and strip
    
    # remove stopwords and stem
    text = [stemmer.stem(word) for word in text.split() if word not in portuguese_stopwords] 
    return ' '.join(text)

df = df[df['length'] > 10]
df['review'] = df['review'].apply(lambda x: process_text(x))
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Toh Hong
# [nltk_data]     Xiang\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package rslp to C:\Users\Toh Hong
# [nltk_data]     Xiang\AppData\Roaming\nltk_data...
# [nltk_data]   Package rslp is already up-to-date!

# %%
word_freqs = {}
for sentence in df['review']:
    for word in sentence.split():
        if word in word_freqs:
            word_freqs[word] += 1
        else:
            word_freqs[word] = 1
            
df_word_freqs = pd.DataFrame(word_freqs.items(), columns=['word', 'freq']).sort_values(by='freq', ascending=False)
print(df_word_freqs.head(20))
sns.barplot(y='word', x='freq', data=df_word_freqs.head(20))
# Out:
#        word   freq
# 36   produt  21244
# 38   entreg  12913
# 3      praz   8533
# 9     compr   7713
# 0     receb   7008
# 23     cheg   6646
# 16    recom   5886
# 2       ant   5728
# 72      bom   4853
# 144     vei   3418
# 45     ótim   3337
# 1       bem   3126
# 6       loj   2950
# 118    qual   2867
# 33      sup   2591
# 116   rápid   2570
# 39     gost   2514
# 71     aind   2453
# 108     tud   2334
# 254     dia   2312
# <AxesSubplot:xlabel='freq', ylabel='word'>

# %%
X = df['review']
y = df['review_score']

# %%
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics import f1_score

def testClassifier(clf, X, y, X_transformer=None, y_transformer=None, plot_confusion_matrix=False, include_f1=True):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)
    
    if X_transformer:
        X_train = X_transformer.fit_transform(X_train)
        X_test = X_transformer.transform(X_test)
    if y_transformer:
        y_train = y_transformer.fit_transform(y_train)
        y_test = y_transformer.fit_transform(y_test)
    
    print(clf.fit(X_train, y_train))
    cross_validation_scores = cross_val_score(clf, X_test, y_test, cv=5)
    print(f"Average 5-fold cross validation score: {sum(cross_validation_scores)/len(cross_validation_scores)}")
    print(f"Score: {clf.score(X_test, y_test)}")
    
    if include_f1:
        print(f"F1: {f1_score(y_test, clf.predict(X_test), average='weighted')}")
    print("\n")
    
    if plot_confusion_matrix:
        ax = plt.axes()
        sns.heatmap(confusion_matrix(y_test, clf.predict(X_test)), annot=True, fmt="d", ax=ax)
        ax.set_title(clf.__str__())
        plt.show()

# %%
from sklearn.linear_model import LinearRegression, LogisticRegression, Ridge, Lasso

testClassifier(LinearRegression(), X, y, TfidfVectorizer(), None, include_f1=False)
testClassifier(LogisticRegression(class_weight='balanced', max_iter=1000), X, y, TfidfVectorizer(), None, include_f1=False)
testClassifier(Ridge(), X, y, TfidfVectorizer(), None, include_f1=False)
testClassifier(Lasso(), X, y, TfidfVectorizer(), None, include_f1=False)
# Out:
# LinearRegression()
# Average 5-fold cross validation score: 0.3029090723797302
# Score: 0.4943399560980898
#
#
# LogisticRegression(class_weight='balanced', max_iter=1000)
# Average 5-fold cross validation score: 0.5604459521489746
# Score: 0.5812732814087369
#
#
# Ridge()
# Average 5-fold cross validation score: 0.607790108909927
# Score: 0.6259924480983605
#
#
# Lasso()
# Average 5-fold cross validation score: -7.949841083965126e-06
# Score: -9.971246145390467e-05

# %%
from sklearn.naive_bayes import MultinomialNB, BernoulliNB, ComplementNB, GaussianNB
testClassifier(MultinomialNB(), X, y, TfidfVectorizer(), None, True)
testClassifier(BernoulliNB(), X, y, TfidfVectorizer(), None, True)
testClassifier(ComplementNB(), X, y, TfidfVectorizer(), None, True)
# testClassifier(GaussianNB(), X, y, TfidfVectorizer(), None, True)
# Out:
# MultinomialNB()
# Average 5-fold cross validation score: 0.6585679307328656
# Score: 0.6716051473078225
# F1: 0.570524988629292
# BernoulliNB()
# Average 5-fold cross validation score: 0.6301221233502814
# Score: 0.646799864544531
# F1: 0.5881731767587479
# ComplementNB()
# Average 5-fold cross validation score: 0.6627159894836533
# Score: 0.6655943108703014
# F1: 0.6005505233938004

# %%
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
testClassifier(KNeighborsRegressor(), X, y, TfidfVectorizer(), None, include_f1=False)
testClassifier(KNeighborsClassifier(), X, y, TfidfVectorizer(), None, True)
# Out:
# KNeighborsRegressor()
# Average 5-fold cross validation score: 0.1600145405618927
# Score: 0.09485817949926012
#
#
# KNeighborsClassifier()
# Average 5-fold cross validation score: 0.517861735913854
# Score: 0.5421605147307823
# F1: 0.46857551610108056

# %%
from sklearn.tree import DecisionTreeClassifier

testClassifier(DecisionTreeClassifier(max_depth=10), X, y, TfidfVectorizer(), None, True)
# Out:
# DecisionTreeClassifier(max_depth=10)
# Average 5-fold cross validation score: 0.5622250379205527
# Score: 0.5706061632238402
# F1: 0.5020031218545823

# %% [markdown]
# Let's also compare between
# - `TfidfVectorizer`
# - `CountVectorizer`

# %%
from sklearn.feature_extraction.text import CountVectorizer

testClassifier(MultinomialNB(), X, y, TfidfVectorizer(), None, True)
testClassifier(MultinomialNB(), X, y, CountVectorizer(), None, True)
# Out:
# MultinomialNB()
# Average 5-fold cross validation score: 0.6644090754193478
# Score: 0.6746528953606502
# F1: 0.5760835885516029
# MultinomialNB()
# Average 5-fold cross validation score: 0.6689803250292131
# Score: 0.6721977649847612
# F1: 0.6158255472088799

# %% [markdown]
# From the results above, there is not much difference between the `TfidfVectorizer` and `CountVectorizer`

# %% [markdown]
# # Predicting sentiment based on review
#
# Instead of predicting the score (1-5), lets predict whether we get a positive/negative review. We shall consider <= 3 as a negative review, and everything else as a positive review

# %%
df['is_positive'] = df['review_score'] > 3

# %%
df.head()
# Out:
#   review_comment_title                             review_comment_message  \
# 0                                   Recebi bem antes do prazo estipulado.
# 1                       Parabéns lojas lannister adorei comprar pela I...
# 2            recomendo  aparelho eficiente. no site a marca do aparelh...
# 3                         Mas um pouco ,travando...pelo valor ta Boa.\r\n
# 4      Super recomendo  Vendedor confiável, produto ok e entrega antes...
#
#    review_score                                             review  length  \
# 0             5                         receb bem ant praz estipul      37
# 1             5  parabém loj lannist ador compr internet segur ...     100
# 2             4  recom aparelh efici sit marc aparelh impress d...     184
# 3             4                        pouc travandopel val ta boa      43
# 4             5     sup recom vend confi produt ok entreg ant praz      72
#
#    is_positive
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True

# %%
X = df['review']
y = df['is_positive']

testClassifier(LinearRegression(), X, y, TfidfVectorizer(), None, include_f1=False)
testClassifier(LogisticRegression(class_weight='balanced', max_iter=1000), X, y, TfidfVectorizer(), None)
testClassifier(Ridge(), X, y, TfidfVectorizer(), None, include_f1=False)
testClassifier(Lasso(), X, y, TfidfVectorizer(), None, include_f1=False)
# Out:
# LinearRegression()
# Average 5-fold cross validation score: 0.2423409300400677
# Score: 0.4034850360961266
#
#
# LogisticRegression(class_weight='balanced', max_iter=1000)
# Average 5-fold cross validation score: 0.8722490354580905
# Score: 0.8785133762275652
# F1: 0.8797086419099718
#
#
# Ridge()
# Average 5-fold cross validation score: 0.5707711037425349
# Score: 0.5836905108659778
#
#
# Lasso()
# Average 5-fold cross validation score: -0.0005502172024271612
# Score: -0.00010042688013611745

# %%
testClassifier(MultinomialNB(), X, y, TfidfVectorizer(), None, True)
testClassifier(BernoulliNB(), X, y, TfidfVectorizer(), None, True)
testClassifier(ComplementNB(), X, y, TfidfVectorizer(), None, True)
# testClassifier(GaussianNB(), X, y, TfidfVectorizer(), None, True)
# Out:
# MultinomialNB()
# Average 5-fold cross validation score: 0.8727571869883682
# Score: 0.8824923806298679
# F1: 0.8822218866020458
# BernoulliNB()
# Average 5-fold cross validation score: 0.8399095855058742
# Score: 0.8538774128005419
# F1: 0.8522401384552559
# ComplementNB()
# Average 5-fold cross validation score: 0.8812231183325492
# Score: 0.8802912292583813
# F1: 0.8813450337432855

# %%
testClassifier(KNeighborsRegressor(), X, y, TfidfVectorizer(), None, include_f1=False)
testClassifier(KNeighborsClassifier(), X, y, TfidfVectorizer(), None, True)
# Out:
# KNeighborsRegressor()
# Average 5-fold cross validation score: 0.10490111940311617
# Score: 0.2782497943978103
#
#
# KNeighborsClassifier()
# Average 5-fold cross validation score: 0.710380359357481
# Score: 0.7225702675245513
# F1: 0.6831086709988089

# %% [markdown]
# We can see that, we are able to classify with ~85% accuracy, the sentiment of the review based on the text of the review

# %% [markdown]
# # Fine Tuning Classifier
#
# Let's use a `ComplementNB` with a `CountVectorizer`. We will also tackle more problems
#
# 1. We will tackle the problem of class imbalance using [SMOTE](https://machinelearningmastery.com/smote-oversampling-for-imbalanced-classification/), a way to synthetically generate minority sample
# 2. We will also do some hyperparameter tuning to figure out the best set of parameters for `MultinomialNB`

# %%
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from imblearn.over_sampling import BorderlineSMOTE 

# Split to train/test sets
X = df['review']
y= df['review_score']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# Transform with our vectorizer
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(X_train)
X_test = vectorizer.transform(X_test)

# FIx class imbalance
sm = BorderlineSMOTE()
X_train, y_train = sm.fit_resample(X_train, y_train)

# %%
params = dict(
    alpha=[0.01, 0.05, 0.1, 0.5, 1.0],
    fit_prior=[True, False]
)
skf = StratifiedKFold(shuffle=True)
cnb = ComplementNB()

clf = GridSearchCV(cnb, params, cv=skf, scoring='f1_weighted')
clf.fit(X_train, y_train)
print(f"Best score: {clf.best_score_}, Best parameters: {clf.best_params_}")

clfNB = ComplementNB(**clf.best_params_)
clfNB.fit(X_train, y_train)

print(f"Validation Score: {clf.score(X_test, y_test)}")
print(f"f1: {f1_score(y_test, clf.predict(X_test), average='weighted')}")

ax = plt.axes()
sns.heatmap(confusion_matrix(y_test, clfNB.predict(X_test)), annot=True, fmt="d", ax=ax)
ax.set_title(clfNB.__str__())
plt.show()
# Out:
# Best score: 0.649466773517, Best parameters: {'alpha': 0.01, 'fit_prior': True}
# Validation Score: 0.5922313993803784
# f1: 0.5922313993803784

# %% [markdown]
# We also have `Ridge` being the best regressor for the problem.

# %%
params = dict(
    alpha=[0.01, 0.05, 0.1, 0.5, 1.0],
    normalize=[True, False],
    solver=["auto", "svd", "cholesky", "lsqr"]
)

skf = StratifiedKFold(shuffle=True)
rdg = Ridge()
clf = GridSearchCV(rdg, params, cv=skf, scoring='explained_variance')
clf.fit(X_train, y_train)
print(f"Best score: {clf.best_score_}, Best parameters: {clf.best_params_}")

clfRegression = Ridge(**clf.best_params_)
clfRegression.fit(X_train, y_train)

print(f"Validation Score: {clfRegression.score(X_test, y_test)}")

# ax = plt.axes()
# sns.heatmap(confusion_matrix(y_test, clf.predict(X_test)), annot=True, fmt="d", ax=ax)
# ax.set_title(clf.__str__())
# plt.show()
# Out:
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# ...
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='svd' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='cholesky' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:610: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 762, in fit
#     return super().fit(X, y, sample_weight=sample_weight)
#   File "C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\linear_model\_ridge.py", line 548, in fit
#     raise ValueError(
# ValueError: solver='lsqr' does not support fitting the intercept on sparse data. Please set the solver to 'auto' or 'sparse_cg', 'sag', or set `fit_intercept=False`
#
#   warnings.warn("Estimator fit failed. The score on this train-test"
# C:\Users\Toh Hong Xiang\anaconda3\lib\site-packages\sklearn\model_selection\_search.py:918: UserWarning: One or more of the test scores are non-finite: [-73.88697315          nan          nan          nan   0.62691999
#           nan          nan          nan -88.70525899          nan
#           nan          nan   0.64349351          nan          nan
#           nan -93.64439459          nan          nan          nan
#    0.64765312          nan          nan          nan -84.05857912
#           nan          nan          nan   0.64445664          nan
#           nan          nan -62.9804325           nan          nan
#           nan   0.63758752          nan          nan          nan]
#   warnings.warn(
# Best score: 0.6476531207197717, Best parameters: {'alpha': 0.1, 'normalize': False, 'solver': 'auto'}
# Validation Score: 0.541245645461884

# %%
def make_predict(clf, vectorizer):
    def predict(text):
        transformed_text = process_text(text)
        transformed_text = vectorizer.transform([transformed_text])
        return clf.predict(transformed_text)[0]
    return predict

reviews = [
    'produto ruim', # bad product
    'produto excelente', # excellent product
    'este foi um ótimo produto que chegou na hora', # this was a great product that arrived on time
    'este foi um ótimo produto, mas chegou tarde', # this was a great product, but it came late
]
    
predictDiscrete = make_predict(clfNB, vectorizer)
predictContinuous = make_predict(clfRegression, vectorizer)

for review in reviews:
    print(f"Discrete prediction: {predictDiscrete(review)}, Continuous prediction: {predictContinuous(review)}")
# Out:
# Discrete prediction: 2, Continuous prediction: 1.6557751359682138
# Discrete prediction: 5, Continuous prediction: 4.480566979319684
# Discrete prediction: 5, Continuous prediction: 3.815680106126536
# Discrete prediction: 2, Continuous prediction: 2.2927752739933247

# %%
review_from_df = df[df['review_score'] == 2].iloc[4]['review_comment_message']
print(predictDiscrete(review_from_df))
print(predictContinuous(review_from_df))
# Out:
# 1
# 2.73029073329451

# %% [markdown]
# # Saving and Loading Models
#
# To save and load models, use `pickle`

# %%
import pickle

vectorizer_filename = 'vectorizer.sav'

pickle.dump(clfNB, open('NBClassifier.sav', 'wb'))
pickle.dump(clfRegression, open('RidgeClassifier.sav', 'wb'))
pickle.dump(vectorizer, open(vectorizer_filename, 'wb'))

# %%
with open('NBClassifier.sav', 'rb') as f:
    model = pickle.load(f)
with open(vectorizer_filename, 'rb') as f:
    vectorizer = pickle.load(f)

predict = make_predict(model, vectorizer)

print(predict("nunca chegou")) # never arrived
print(predict("belo embrulho")) # beautiful package
print(predict("qualidade ruim")) # bad quality
# Out:
# 1
# 4
# 2

# %%
df['predicted_score'] = df['review'].apply(lambda x: predictDiscrete(x))
df['difference'] = abs(df['review_score'] - df['predicted_score'])
df.head()
# Out:
#   review_comment_title                             review_comment_message  \
# 0                                   Recebi bem antes do prazo estipulado.
# 1                       Parabéns lojas lannister adorei comprar pela I...
# 2            recomendo  aparelho eficiente. no site a marca do aparelh...
# 3                         Mas um pouco ,travando...pelo valor ta Boa.\r\n
# 4      Super recomendo  Vendedor confiável, produto ok e entrega antes...
#
#    review_score                                             review  length  \
# 0             5                         receb bem ant praz estipul      37
# 1             5  parabém loj lannist ador compr internet segur ...     100
# 2             4  recom aparelh efici sit marc aparelh impress d...     184
# 3             4                        pouc travandopel val ta boa      43
# 4             5     sup recom vend confi produt ok entreg ant praz      72
#
#    is_positive  predicted_score  difference
# 0         True                5           0
# 1         True                5           0
# 2         True                5           1
# 3         True                4           0
# 4         True                5           0

# %%
badly_classified_reviews = df[(df['difference'] > 2)]
for index, row in badly_classified_reviews.iterrows():
    print(row['review_comment_title'], row['review_comment_message'], row['predicted_score'], row['review_score'])
    print('==')
# Out:
# Não chegou meu produto  Péssimo 5 1
# ==
#  Sempre compro pela Internet e a entrega ocorre antes do prazo combinado, que acredito ser o prazo máximo. No stark o prazo máximo já se esgotou e ainda não recebi o produto. 5 1
# ==
# Muito bom. Recebi exatamente o que esperava. As demais encomendas de outros vendedores atrasaram, mas esta chegou no prazo. 1 4
# ==
#  O produto não chegou no prazo estipulado e causou transtorno, pq programei a viagem de férias do meu filho, baseado no prazo. Moro na Bahia e ele em Cuiabá sozinho. Agora, a casa está vazia.  4 1
# ==
#  Gostei muito do jogo de banho.A estampa florida, o bordado, tudo muito bonito. Ótimo produto. 2 5
# ==
# prazo entrega Espero receber esta semana, o que não seria tão extravagante, porém...mais atrazo do que isso me faria desistir do baratheon. 1 5
# ==
#  Ainda não tive a oportunidade de testar 1 5
# ==
#  nada a declarar 1 5
# ==
#  até agora não recebi o produto. 4 1
# ==
#  Chegou hoje
# sem comentários 1 4
# ==
#  Muito bom! Aquilo que esperava! 1 5
# ==
#  Acho q deveriam mandar por sedex ao invés de pac 1 5
# ==
#  produto entregue conforme anunciado. 1 4
# ==
#  Até hoje estou satisfeito com a sbmarino 1 5
# ==
# Produto e entrega ótimos Apesar da demora em expedir a nota fiscal, depois de expedida a entrega foi rápida e o produto veio bem embalado. Recomendo. 1 5
# ==
#  Ótima compra. Ótimo produto. Só senti falta de algum comunicado entre a compra e a chegada do produto, só contato. Mas valeu. 1 4
# ==
#  Os pincéis vieram amassados, não condiz com algumas fotos, mas condiz com a descrição. São fracos, não cabem na case e um veio descolado  4 1
# ==
#  Muito bom o produto e preço cobrado! 4 1
# ==
# 10 Gostei muito , o objeto veio o mesmo comprado, já comprei em outras lojas e veio outra cor ñ Gostei! Com lannister tudo ok. 2 5
# ==
#  Excelente produto indico a qualquer pessoa. 5 2
# ==
#  Não recebi o produto.e agora? 4 1
# ==
# Regular  Loja em si é boa pena a americana nao da suporte ao cliente  2 5
# ==
#  Entrega rápida produto conforme anunciado 1 5
# ==
# Otimo produtos Ainda nao instalei mais gostei muito 2 5
# ==
#  Nao foi entregue na minha casa , por isso nao gostei , nao tenho tempo de esta indo nos correios.. 4 1
# ==
# Meu produto não chegou  5 1
# ==
#  Continuem assim, com essa responsabilidade com o consumidor, tanto no produto, quanto no prazo de entrega. Primeira vez que compro e vou comprar muitas. Obrigado. 1 5
# ==
# capa de notbuk  Veio conforme o anunciado simples mais bonita.  1 4
# ==
#  Recebi, a bolsa é diferente mas gostei estava previsto pra 31 de janeiro estava achando muito tempo porque é pra escola e estou aguardando o vale compra da primeira compra da bolsa que não deu certo  1 4
# ==
#  ******************* 1 4
# ==
#  Produto não foi entregue! 5 1
# ==
# Péssima  Recebi o produto que eh falso quero meu dinheiro de volta  1 5
# ==
# ENTRAGOU NO PRIMEIRO DIA ABRI PROTOCOLO PARA DEVOLUÇÃO, PRODUTO DE BAIXA QUALIDADE DEU PROBLEMA NO PRIMEIRO DIA DE USO.
#
# lannister VIROU UM MERCADO LIVRE....6 PEDIDOS 6 PROBLEMAS  4 1
# ==
#  Otimo material bem resistente espaçosa 👏👏👏 gostei! 1 4
# ==
#  Podem comprar sem medo 2 5
# ==
# Não entregou no tempo . Sem pontualidade não da satisfação ao cliente. 5 1
# ==
#  Produto chegou rapidamente e conforme o anunciado. 1 5
# ==
#  só acho que poderia ter comprado mais cartuchos, mas não as fiz porque cada cartucho veio em um frete diferente, coisa que poderiam ser colocados em um único pacote, o que baratearia o frete. 2 5
# ==
#  Conforme já solicitei, preciso fazer a devolução. Ele não foi entregue no prazo que eu precisa. Já solicitei por aqui e já entrei em contato com o vendedor. Estou no aguardo para fazer a devolução. 1 4
# ==
#  Aida nao recebi o produto 1 4
# ==
#  ENTREGA MUITO DEMORADA, COMPREI EM 26/03/2018 E ATÉ AGORA NÃO RECEBI OS PRODUTOS 4 1
# ==
#  O produto chegou conforme anunciado. Gostei. 1 4
# ==
#  Dentro do prazo e informacoes do encaminhamento do produto de forma clara 2 5
# ==
# Esclarecimento Boa noite na compra diz wireless 150mbs Multilaser mais 3g não teria que vim o modem 3g que conecta no USB nele. 5 2
# ==
#  Além de ñ cumprir com o prometido no caso aentrega a loja ainda dá esclarecimento errado informado que o endereço está errado 4 1
# ==
#  O PRODUTO É BOM, MAS QUASE 2 MESES PARA RECEBER !!!! 5 1
# ==
#  Melhor site de compras pela internet! 2 5
# ==
#  eu tinha aberto a reclamação solicitando o reenvio ontem e durante a tarde aconteceu
#
# grato 1 5
# ==
# Balancim 100 Ainda não pode avaliar o produto. Estou aguardando a Matriz e os botões, também comprados no site das Lojas lannister.
# Estou estranhando o fato da nota fiscal desses produtos não ter sido emitida.  1 5
# ==
# Bom cofre Cofre com bom espaço interno e prateleira para facilitar a organização. Bom produto. 1 5
# ==
#  Já solicitei devolução do produto. Veio amassado, parece que houve uma queda 4 1
# ==
#  nao veio o produto que pedi veio um quite de marmitas 10 peças eu comprei um jogo de panelas 1 4
# ==
#  Não abri a caixa ainda !  1 4
# ==
# Muito bom  Adorei os produtos somente achei muito ruim ter de pagar 2 fretes para o mesmo produto do mesmo vendedor  2 5
# ==
#  Há varios anos compro na loja stark e até agora, nada tenho a reclamar. 1 5
# ==
#  Ainda não recebi o produto  2 5
# ==
#  e a melhor loja para fazer compras 1 5
# ==
#  Mais agilidade na entrega  5 2
# ==
#  Lugar ótimo pra fazer compras ! 1 5
# ==
#  Ate agora nao revebi o produto.
# Espero que ao menos a pontuação tenha sido feita de acordo com a promoção. 4 1
# ==
#  Me venderam um produto que não tinham para entregar 5 1
# ==
#  só recebi um dos produtos...
# até o momento não recebi o Conjunto Quadros Decorativos Fé Amor Família com Vidro A4 ...
# no aguardo 5 2
# ==
# RECOMENDO SIM ASPIRADOR MUITO BOM, LEVE E FÁCIL DE MANUSEAR! 2 5
# ==
# Otima  Sistema operacional de compra fácil de ser manuseado e compreendido. Entrega rápida e o metros comprado corresponde com o da propaganda. Compraria novamente . 1 4
# ==
#  Produto excelente para jogar no PS2.
# Consta que serve também para PS3 e PC, vou testar. 2 5
# ==
#  Material de otima qualidade! 1 4
# ==
#  Minha nota é 10 2 5
# ==
#  MATERIAL MUITO BOM 1 5
# ==
#  recomendo a loa pois cumpriu o prazo certinho mas o produto é muito ruim...pessima qualidade. 5 2
# ==
#  Produto enviado com muito carinho e atenção !!!
# Adorei. 1 5
# ==
#  Entrega rápida antes do prazo, objeto muito bom de acordo com o anuncio. 1 4
# ==
#  Produto de ótima qualidade e entrega turbo! 1 5
# ==
#  Produto enorme e confortavel. 1 5
# ==
#  O produto não foi entregue na minha casa
# Tive q ir buscar na agência
# Paguei 20 reais de frete é ainda assim não recebi em casa 4 1
# ==
#  Mada a declarar 2 5
# ==
#  Tudo dentro do esperado, a não ser o correio que trouxe a embalagem parecendo estar atropelado por um trem, tive de pessar os tres produtos pra ver se tinha perda, pois estava vazando. 1 5
# ==
#  Não recebi até agora a mercadoria.  4 1
# ==
#  LOJA CONFIAVEL, MAS AINDA NÃO RECEBI O PRODUTO 1 4
# ==
#  Comprei o produto no dia seguinte recebi um e-mail do stark dizendo para eu tentar novamente com outro cartão , fiz a compra e a compra saiu em duplicata pedi o cancelamento desse. 1 4
# ==
#  Durante o transporte o correio informou que o produto havia se perdido, mandei um e-mail para a empresa e não me deram resposta, mas, o produto chegou na minha residência depois de alguns dias. 1 5
# ==
# Recomendo. Apesar da demora na entrega. No mais foi tudo bem. 5 2
# ==
# Muito bom! Material entregue no prazo . 1 5
# ==
#  Pedido entregue antes do prazo, voltarei a comprar nessa loja 1 4
# ==
#  comprei três cabos USB,macho e femea,cada um com 5m. Dois vieram com defeitos ,o windows não o reconhece. 4 1
# ==
#  Gostei muito, cores lindas.
# O produto vem em madeira leve e parece que é um material tipo contact. Leve como uma placa;
# Mas muito bonito.  1 4
# ==
# Muito bom! Gostei do Fone pois tem uma boa qualidade som, fiquei algumas horas (+ ou - 3h) com ele conectado celular e nada de pedir pra carregar. Ainda não testei o radio, mas acredito que esta ok.
#  1 5
# ==
# Primo do 10 de valiacao Recebin antes do prazo ainda esse ano vou compa de novo com vcs 1 5
# ==
#  estou esperando a segunda parte da encomenda só recebi uma parte do pedido.... continuo no aguardo
#
# Obrigada 1 5
# ==
#  preço bom, entrega no prazo 4 1
# ==
#  Produto veio no tempo esperado! 1 5
# ==
# Muito Ruim Comprei 6 cartuchos, recebi apenas 4 unidades após o prazo de entrega, e ate hoje estou tentando entrar em contato para uma solução, mas sem sucesso.  5 1
# ==
#  Produto está até hoje na unidade do correio em Cajamar e não chegou em minha casa. Estraviou? 4 1
# ==
#  Produto não foi entregue  5 1
# ==
#  Foi tudo muito rápido, a compra, o pagamento e a chegada. Só faltou o próximo produto. O que deixaram a desejar, foi que eu comprei pelo site, porém asessei na loja e o vendedor não me explicou. 1 4
# ==
#  Eu comprei um celular smartphone , não chegou não recomendo comprar nesta loja targaryen e lannister porque não chegou meu produto. Eu comprei está data,07/06/2017. Era pra chegar no dia .05/07/2017. 5 1
# ==
# solicitei devolução não obtive retorno até o momento 1 4
# ==
#  Estou aguardando espero que chegue logo 1 4
# ==
# nao foi o esperado no mostroario e um e o produto e outro 1 5
# ==
#  o problema foi com os Correios que continua com um serviço vergonhoso. 1 4
# ==
#  Produto de otima qualidade, ja compro das lannister faz algum tempo, e nunca me decepcionei 1 5
# ==
# Bom Paguei pelo
# Que comprei  1 4
# ==
# RECOMENDO PRODUTO VEIO COM VENCIMENTO PARA DEZEMBRO, COMPREI OUTROS COM VENCIMENTO DE 2 ANOS.
#  1 5
# ==
#  Eu recomendo para outras pessoas 1 5
# ==
# Maquina de Tosa  Ainda não foi feito tosa com ela , mais em principio muito boa  1 4
# ==
#  LOJA EXCELENTE A ANOS QUE COMPRO AQUI SÓ TIVE UM TRANSTORNO NA HORA DA COMPRA, POIS COMPREI TAMBÉM UM PAINEL E NA FINALIZAÇÃO DA COMPRA TAVA PARCELADO TUDO JUNTO E NO FINAL PARCELOU SEPARADO. 1 5
# ==
# Embalagem inadequada Tudo ocorreu beleza, só que a embalagem foi inadequada, não ofereceu proteção ao item comprado , que possuiu um CD que chegou quebrado. 1 4
# ==
#  A entrega foi no prazo,O relógio é muito bonito só pensei que ele seria maior, mais fora isso não tenho o que reclamar 1 4
# ==
#  muito obrigado
#  5 1
# ==
#  produto conforme anunciado entrega muito rapida 1 5
# ==
#  Conforme o esperado 1 5
# ==
# Otima Apesar da greve dos caminhoneiros não houve muito atraso. 1 5
# ==
#  Produto original e lacrado. Nota 10. 2 5
# ==
#  O tapete veio correto porém todo dobrado. Coloquei ele esticado para ver se irá desamassar. Caso não desamasse, devolverei em 3 dias. 1 4
# ==
#  Produto de 1 qualidade. 2 5
# ==
#  Como tudo da FUNKO, super valeu a pena  1 5
# ==
#  produto muito bom, com material resistente.  1 4
# ==
#  já está com quase um mês que fiz o pedido e o produto ainda não chegou. 5 1
# ==
#  O produto não é de boa qualidade, e seu resultado não é o esperado! Acho que perdi dinheiro. 1 4
# ==
#  Toner não funciona. Impressão de péssima qualidade. Quase não dá pra ver a impressão  5 1
# ==
# Não quero avaliar  1 4
# ==
# Ainda estou testando Ainda não testei. Mas a embalagem é impecável, tudo separado certinho, vem dentro de uma bolsa compartimentada que me agradou muito. 1 5
# ==
# excelente serviço Tudo transcorreu conforme acertado.. Gostaria até em adquirir, que não consta em tela, dessas capas (tamanho por encomenda: enviando a medida), para dois som de mesa, é viável? 1 5
# ==
#  O PRODUTO FOI ENTREGUE EM LOCAL ERRADO. ENTRETANTO CONSEGUI RECEBER, AGUARDO A ENTRAGA DA MÁQUINA DE LAVAR NO ENDEREÇO CORRETO: RUA GENERAL IVAN RAPOSO, 44 AP 101- BARRA DA TIJUCA, RIO DE JANEIRO 1 4
# ==
#  Chegou em dois dias muito bom 2 5
# ==
#  Gostei muito! Linda!
# Ainda não usei... não posso avaliar se mantem gelado legal.  1 5
# ==
#  Produto não atendeu as expectativas 4 1
# ==
#  O cumprimento do prazo ocorreu, entretanto a qualidade do produto foi péssima. O produto não vem em embalagem original da Philips e apresenta diferenças entre a lamina original. O uso demonstrou-se pe 5 1
# ==
#  Confortavel 2 5
# ==
#  O pedido foi feito duas vezes e não foi entregue.A primeira vez foi por que o número da casa estava errado, a segunda nÃo recebi justificativa. 4 1
# ==
# Produto não entregue Produto não entregue 5 1
# ==
#  Além da demora para emitir a nota fiscal, a demora para a devolução do dinheiro, em caso de cancelamento da compra, demora uma eternidade.
# Já faz 2 semanas que solicitei o cancelamento e nada. 4 1
# ==
#  Gostei e recomendo!!
# É de confiança!! 5 1
# ==
#  O relógio é lindo, correspondeu as expectativas. Só na hora de fazer os ajustes que achei bem difícil. Precisei ir numa relojoaria para ajustarem para mim. Hehehehehe  1 5
# ==
#  Muita dificuldade de fazer contato com a loja via telefone. 1 4
# ==
#  Fiquei muito feliz cm o produto e cm o prazo de entrega  2 5
# ==
#  Produto veio com lacre violado.
# Embora aparentemente parece que não foi usado, mas o lacre violado não passa segurança. Ainda mais quando a gente compra para dar de presente, o que foi o caso.
#  4 1
# ==
#  Apesar da demora dos correios,adoro comprar nas lojas lannister  1 5
# ==
#  Pra quem não se adapta a película de vidro a película de vidro, essa é uma boa opção. 2 5
# ==
#  Gostaria que criassem uma forma de entrega, melhor, pois pelo Sedex temos que retirar nos correios ,e a mesma fica muito longe de minha residência,no mas o produto é perfeito
#  1 5
# ==
#   Tudo de acordo com o combinado. 4 1
# ==
#  O prazo de entrega acaba dia 3/1/18. Eu não comprarei no baratheon quando o prazo de entrega for muito grande. 5 2
# ==
#  Recebi a película quebrada. Estou tentando a troca do produto.  1 4
# ==
#  As compras que fiz no site das lannister, sempre deram certo.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  1 4
# ==
#  Sempre comprei no site e fique muito satisfeito infelizmente pela primeira vez aconteceu esse imprevisto
# Espero que o problema seja resolvido em breve pois preciso da mercadoria 4 1
# ==
#  Pois por baratheon é mais rápido.
# Por exemplo
# Na compra no baratheon agente compra hoje.
# Exemplo.
#
# Na sexta-feira chega o produto que agente comprou de
# Essa loja chegou faiz na data que foi co 5 2
# ==
#  Produto não corresponde a imagem de venda  4 1
# ==
#  QUANTO O MPRAZO FOI A PENAS DIFICUDADE QUANTO O ENDEREÇO NO MAIS FOI MARAVILHOSO
#  1 5
# ==
#  A única questão foi um comunicado que recebi dizendo que não receberia o produto e até mesmo um link para "cancelar" a compra. 1 4
# ==
#  Não recebi o produto e nem tive resposta da loja para saber o que aconteceu. Até agora só estou tendo problemas com a compra.  4 1
# ==
#  Adorei o produto! 2 5
# ==
#  Gosto muito de comprar no baratheon
# Dessa vez me decepcionei não recebi o meu produto. 1 4
# ==
# entrega rapida Bom e rapido na entrega 5 2
# ==
#  Comprei errado e me ferrei! Excelenta site para compra mas os serviços acessórios de pós venda, orientação de troca, arrependimento não funcionam!  5 1
# ==
#  Continue assim.o que tiver no site mantenha sempre 1 4
# ==
#  produto n foi entregue 5 1
# ==
# Produto não condiz com es A descrição do produto fala q serve para veículos a parti de 2007 O que não é vdd tenho q fazer a troca do produto só serve para modelo 2009 pra frente
#  4 1
# ==
#  Haste conforme anunciado, preço abaixo do mercado! 1 5
# ==
#  Produto de qualidade, nem parece que meu zenfone 3 zoom está com película, já que ela cobre a tela inteira, realmente protege. 2 5
# ==
#  Ajudem a rastrear uma das 3 prateleiras que faltou, só chegaram 2 delas... 2 5
# ==
#  Voltarei a comprar 1 5
# ==
#  Foi recebido apenas a pulseira de aço !
# O kit com as duas pulseiras não veio o correio informou q só veio uma caixa com uma pulseira !!
#  4 1
# ==
#  Este pedido eu recebi , mas tenho outro feito antes deste que ainda não chegou... 2 5
# ==
#  Eu comprei a primeira Bota e veio a numeração certa. Ela é muito confortável. Valeu a pena. 1 4
# ==
# pagamento gostaria de saber de houve o debito correto no meu cartão. tive cartão clonado.  1 4
# ==
#  A empresa faz de tudo para agradar o cliente e fez isso com qualidade. 1 5
# ==
# Muito bom O sistema é prático, e procura tirar as duvidas do cliente. Com várias opções.  1 4
# ==
#  Encomendei 2 carrinho da mesma loja
# Mais recebi somente um com a nota de dois carrinhos
# Estou no aguardo pelo outro produto 2 5
# ==
#  Penso que o envio poderia ser mais barato se fosse em contato junto. Ex. Comprei 3 unidades que poderiam vir numa mesma embalagem.
#
#  1 4
# ==
#  facil acesso no site, entrega no tempo estipulado.
#
# PERFEITO!!! 2 5
# ==
#  Tem que ser mais rapido a entrega  5 1
# ==
#  Estou muito chateada pois comprei um produto(kit de Pincéis) e veio um outro produto(Bare Lifts).
# Enviei um e-mail no mesmo dia que chegou (22/03/2017) e até agora não obtive resposta. 5 1
# ==
#  Chegou bem antes do prazo e conforme o anuncio. Muito bom atendimento! 1 5
# ==
# É O MÁXIMO, SUPER RECOMEN  2 5
# ==
#  O produto comprado , chegou nos correios , mais os correios mandaram a cartinha de confirmaçao que o produto estava na unidade , depois do prazo . Poderia fazer o envio do produto de novo.? 1 4
# ==
# nota 10 vocês e muito pontual 5 1
# ==
#  lannister ótima vcs dão valor as seus cliente.obrigado 1 5
# ==
#  fiz essa compra pelo baratheon comprei um conj. de bolsas para maternidade diz que seria entregue pelo targaryen ate agora nao chegou.
# comprei na mesma compra lustres e ja chegaram ate mesmo antes do praz 5 1
# ==
#  Nem o targaryen e nem o intermediário stark me responderam ou deram qualquer satisfação pelo produto que paguei a vista. Prazo de entrega: 15/03. Produto foi pago quase 1 mês atrás 5 1
# ==
# elogio comecei usar o produto ontem, nao tenho como avaliar a eficacia. entrega rapida e bem embalado. 1 5
# ==
# Produto com cor diferente O produto é de boa qualidade, porém, comprei na cor branco e recebi na cor rosa. Não efetuei a troca pois para a utilização a cor não iria interferir, e estava com urgência. 1 4
# ==
#  o único problema é que no anuncio não fala se é de ilhós ou tiras, acabei comprando achando que fosse de ilhós e infelizmente não era,. pois deveria constar no anuncio. Mas o produto é bom. 1 4
# ==
#  O produto veio errado. o que é um transtorno visto que tive vários problemas com a entrega. 4 1
# ==
#  Adorei o pingente, vem na caixinha e com certificado de garantia. 1 5
# ==
# Facil troca Otimo produto e de fácil substituição no aparelho. Demorei nem 2 min para troca 2 5
# ==
#  Recomendo esta loja, mas por conta dos correios, houve atraso na entrega. 1 4
# ==
#  demora muito pr entregar 1 4
# ==
#  Recebi, porém com atraso na entrega.
# Mas produto chegou com tudo ok! 1 4
# ==
#  O produto não foi entregue! 5 1
# ==
#  Eu gostei muito dos meus produto 4 1
# ==
#  produto cortina nao veio e agora? 4 1
# ==
#  Gostei do produto mas na entrega deixou a desejar, e não dão informações ao cliente sobre a entrega.. mas o produto é ótimo e lindo!  1 4
# ==
#  Produto de acordo com o anunciado e entrega antes do prazo 1 5
# ==
#  Ha muitos anos que sou cliente da stark, e só tenho visto mais evolução dessa loja estão de parabéns 1 5
# ==
#  O suporte d mesa é muito bom, mas a tampa é muito frágil. A minha quebrou comigo tentando abrir. 1 4
# ==
#  Recomendo material com qualidade e preço muito bom.
#  1 5
# ==
# Não Gostei. O produto veio desbotado, um aspecto de produto velho e pouca qualidade, no site parece ser lindo. Caso tivesse visto o produto antes com certeza não compraria.
# Não recomendo. 4 1
# ==
#  Produto falsificado código de autênticidade falso. 5 1
# ==
#  Ajudem a rastrear uma das 3 prateleiras que faltou, só chegaram 2 delas... 2 5
# ==
#  Produto está atrasado  1 4
# ==
#  O produto chegou em 3 dias. 1 5
# ==
#  Meu esposo recebeu, estou no interior e quando a mercadoria chegar vou conferir. Eu comprei e ele não pode confirmar o pedido até que eu veja. Kelly 1 5
# ==
#  O site diz que são toalhas felpudas, mas na vdd são horríveis e finas. Me decepcionei muito! De fato, são lindas porém usarei somente para decoração  5 2
# ==
#  Produto bom. Porem pedi uma base que tem os ledes verdes e veio outra completamente diferente da que comprei e que era a do anuncio.  1 4
# ==
#  Otima e chegou em bom estado .. Não substituí a prancha mas ajuda muito no dia a dia .. Como não gosto de pranchar pq acho chato ela me ajudou mt  2 5
# ==
#  Recebi tintas que não eram originais, imediatamente entrei em contato com a loja e recebi o valor de volta.  1 5
# ==
#  Produto de qualidade  2 5
# ==
# Recomendo  Recebi o produto como anunciado, o mesmo funciona como prometidos. 1 5
# ==
#  Não entendi o que houve. No site consta que meu pedido foi entregue, porém, não chegou a minha casa. 4 1
# ==
#  o melhor site para comprar. 2 5
# ==
#  Gostei do produto, porém o visor do sensor está trincado em 2 partes, por ser um produto novo não deveria estar com estas características, como está funcionando direito deixei passar.  1 4
# ==
#  Boa Tarde! Há possibilidade de trocar o produto? O marrom não combinou com nada na minha sala. Gostaria de trocar pelo bege claro ou cinza claro. Por favor me dá um retorno. Desde já agradeço 1 4
# ==
#  Produto arranhado! 4 1
# ==
#  Inicialmente o pedido veio incompleto, passei uma msg a lannister (sem receber a resposta), recebi o restante do pedido 2 dias depois. 1 4
# ==
#  Pedido chegou no prazo, produto de acordo com o anunciado. 1 4
# ==
#  Recomendo mas precisa melhorar o rastreamento dos produtos 1 4
# ==
#  realizei a compra e no site tinha uma data para entrega só que essa data não foi cumprida  5 1
# ==
#  Produto não corresponde com o produto da imagem 4 1
# ==
#  Comprei cartucho compatível com a impressora Deskjet 4580 , cartucho colorido 21 ml.
# Recebi com 17 ml e na embalagem não consta o número de minha Deskjet. . O que faço ?
#  1 4
# ==
#  Produto de qualidade ruim, não cabe na cama queen, que foi o tamanho adquirido. 5 2
# ==
#  Apesar dos transtornos causados, recomendo e continuo comprando nesta loja, não pode ser avaliada como não boa, imprevistos acontecem, ainda aguardo a entrega. 1 4
# ==
#  Eu recomendo a compra desse produto , muito bom. 1 4
# ==
#  O produto chegou antes do prazo, com todas as fases do processo documentadas. Super recomendo.
#  1 5
# ==
#  Gostei, muito prática, leve, só falta avaliar a duração da carga da bateria. 1 4
# ==
#  A transportadora é excelente recebi antes do prazo porém um dos meus produtos veio com cor divergente, espero que eu tenha um retorno. 1 5
# ==
#  O produto foi roubado do veículo dos correios. O vendedor reenviou um novo produto.Ainda não recebi, por isso estou avaliando a atitude da loja em me contactar e apresentar uma solução. 1 4
# ==
#  adorei este kit 1 5
# ==
#  Gostei de comprar nas lannister, envio rápido e sem problemas 4 1
# ==
# recomendo Solicitei a troca do tapete antes da entrega. Porém, era para na entrega eu nao receber e o meu condomínio recebeu. O produto não foi aberto e preciso fazer a troca por um tapete 3x2. Estou aguardando 1 4
# ==
#  Sempre comprei nessa loja, espero que seja somente um falha dos correios, tenho certeza que resolvera essas situação do meu produto.
#   1 4
# ==
# Carregador de baterias  Ainda não testei  2 5
# ==
#  Fiz a compra e não entregou em minha casa. Fiz o cancelamento e ainda recebo estes e-mail enchendo o saco. 4 1
# ==
#  Recebi o produto conforme anunciado dentro do prazo. 1 4
# ==
# Cartucho Tinta HP Chegou dentro do prazo. 1 5
# ==
#  Produto conforme anunciado... Acho que o prazo de entrega poderia ser menor, mas foi cumprido.
#  1 4
# ==
#  Quanto a entrega foi super rápida como sempre e referente ao produto como hj é o segundo dia que uso ainda não sei os resultados. 1 5
# ==
#  A carteira é pequena, e não ocupa muito lugar no bolso ( excelente ). 1 5
# ==
#  O produto até agora não fez efeito espero que faça nos próximos dias 1 5
# ==
#  Recebi em dia porem ficaram faltando 3 tampoes que constavam no pacote.
#
# Falei com a central estou aguardando retorno..
# protocolo 2518040903759 1 4
# ==
#  se precisar voltarei sim a comprar 1 5
# ==
# Controle remoto Funciona perfeitamente 1 5
# ==
# Pedido não entregue  Se não me derem uma posição quanto o meu pedido não entregue terei que tomar minhas providências na justica para sanar meu problema. 5 1
# ==
#  Entrega rápida e produto conforme anunciado. 1 5
# ==
#  2° vez que compro e recomendo de muita qualidade, só quem usa ou já usou sabe disso. 1 5
# ==
#  adoro fazer comprar pelo sai-te  2 5
# ==
#  Sem problemas na execução do pedido, satisfação.  1 5
# ==
#  Otima loja para compras on line 1 5
# ==
#  Ainda não utilizei as embalagens to aguardando a máquina chegar 1 5
# ==
#  material de boa qualidade. estou satisfeito. 1 5
# ==
#  O material decepcionou um pouco. 1 5
# ==
#  Comprar na stark e comprar certa entrega e atualiza o status do pedido via email recomendo a todos 1 5
# ==
#  Ainda não instalei o produto, mas farei o mesmo na próxima semana 2 5
# ==
#  Pinceis não atendeu minha expectativas.. 4 1
# ==
#  Na compra o produto aparenta ser diferente e quando veio aparenta ser exatamente qualquer película do mercado, mas nem apliquei 5 2
# ==
#  A cadeira veio com problema no assento 4 1
# ==
# bom produto condi plenamente com o anuncidao. 1 5
# ==
# Bom Por favor preciso que resolva meu problema pq gosto muito dessa loja mais meu pedido veio errado 1 4
# ==
#  Recebi o produto no prazo, mas solicitei devolução. Estou aguardando instruções pra devolução  1 4
# ==
# Ruim Nao se vende e so depois de 1mes avisa nao ter oproduto  5 1
# ==
#  tirando o detalhe de a cadeira vir com algumas manchas, tanto na parte branca como na rosa manchada de preto, o material é um pouco mais fragil. mas mt bonita, vale pra quem quer mesmo com esse estilo 1 4
# ==
#  Enviaram o produto errado pra mim!
# Na loja virtual estava mostrando o produto original, eu comprei, e chegou um produto totalmente diferente! Quero outro, ou meu dinheiro de volta!!! 1 4
# ==
#  a até agora não recebi 4 1
# ==
# Entrega no prazo Produto entregue no prazo mesmo com a crise na semana passada da greve dos caminhoneiros 1 5
# ==
# Boa! Capinha e muito boa, mas a película e horrível.  1 4
# ==
#  O produto chegou correto. O problema foi a demora na entrega. 4 1
# ==
#  Adorei chegou antes do prazo a rede é grande cabe duas pessoas nela adorei a mercadoria 1 5
# ==
#  Meu gatinho adorou, pode ser cama ou toca, é macia e bonita!  1 5
# ==
#  boa compra e material! 1 4
# ==
#  estou livre dos pernilongos. amei 1 4
# ==
#  Produto de qualidade. 2 5
# ==
#  Nossa muito linda só que eu pedi nossa senhora Aparecida e veio de Fátima,mais muito linda amei. 1 5
# ==
#  A capa flexível é excelente, mas a película de vidro não é apropriada para o Zenfone 3 Zoom pois as bordas não cola, então ficou descolado e por então acho que vc vai proteger. 2 5
# ==
# LANERNA DIFERENTE Uma lanterna bem diferente para uso geral. 2 5
# ==
#  Muito bom chegou até ates do que eu esperava 1 5
# ==
#  Muito bom.cabelo fica lisinho 1 5
# ==
#  Muito bom produto minha mae adorou estão de parabéns tudo no prazo certinho 1 5
# ==
#  amamos o filtro. indico pra quem busca saúde. 1 5
# ==
#  CONFORME O ANUNCIO, RECOMENDO 1 5
# ==
# Positivo Muito bom 2 5
# ==
#  O produto enviado não condiz com o visto nas fotos da propaganda. É de péssima qualidade, não atende as expectativas e não serve para o fim que foi adquirido, além do atraso na entrega.Quero devolver 5 1
# ==
#  Esta é a terceira vez que compro o produto. Só tenho elogios a fazer. 1 5
# ==
# Ótimo Só que na descrição do produto, consta q vem com 3 baterias, mas veio só uma, o que aconteceu? 1 4
# ==
#  Boa noite, recebi os produtos antes da previsão dada, porém ainda não usei , como tenho comprado produtos na lannister .com , não tive problemas penso que estes que acabei de comprar seja igualmente  1 5
# ==
# super recomendo Ótimo atendimento em todos os níveis: Rastreamento, passo a passo da compra desde a confirmação, logística de entrega pelo site da lannister e correio, entrega antes do prazo, logística perfeita.  1 5
# ==
#  Apesar de estar dentro do prazo prometido, demorou quase 3 semanas para chegar. Prazo muito além do praticado no mercado. 5 2
# ==
#  faltou as quatro pulseiras..
# só veio 3 pulseiras na embalagem..
# eu efetuei duas compras.. uma de um kit de 3 pulseiras e outra com um kit de 4 pulseiras..
# só chegou o kit de 3 pulseiras..  4 1
# ==
# Bom Não veio a embalagem certa 4 1
# ==
#  O produto é nota 10. 2 5
# ==
#  Falta ser entregue o suporte para os pés. Só chegou as vasilhas 4 1
# ==
#  è a segunda ou terceira vez que compro. Estou satisfeito.
#  1 5
# ==
#  A loja não cumpriu com o prazo de entrega informado, que seria "até" 08/08/2018. 4 1
# ==
#  Voltaria a comprar nesta loja... 1 5
# ==
# Solicitei o cancelamento  Em função da voltagem não ser a da minha região solicitei o cancelamento da compra... Estou aguardando o estorno do valor pago no cartão.
# Grato 1 5
# ==
# Produto pirata O produto não veio correto pois é pirata e não estava descrito isso na descrição do produto. Estou entrando em contato para trocar pelo original que deveria ser enviado 1 5
# ==
#  como se esperava 1 5
# ==
# Satisfação garantida Farei outros pedidos 1 5
# ==
# não recomendo minha película de vidro chegou toda trincada! preciso de uma inteira,  4 1
# ==
# Recomendo Ola Boa noite. Abri a encomenda Mt ansiosa pq amo este perfume... Mais qd abri vi que veio o perfume errado. Eu pedi errado, sem perceber. O q quero é o azul, nao o roxo. Posso trocar, por favor ! 🙏  1 5
# ==
#  Não recebi a NF da minha compra. Exijo a entrega da NF. 1 4
# ==
#  satisfeitissima 1 5
# ==
#  Era pra ter chego dia 14 e até agora nada  4 1
# ==
#  Efetue a compra de um produto e acabei recebendo outro, totalmente diferente. 2 5
# ==
# REDE BOA Comprei duas redes que na descrição dizia que eram de 4,40 metros, apenas uma é desse tamanho e a outro é bem menor e mais fina. a rede maior veio com falhas na costura. mas são boas redes. 1 4
# ==
#  Produto chegou rápido em ótimas condições e com um preço bem acessível.  2 5
# ==
# Recebi Errado Pedi o Pure Seduction e veio o Love Spell. 5 1
# ==
#  Sem comentários 1 5
# ==
#  muitom bom o produto e o site recomendo sim.... 1 4
# ==
#  Produto de qualidade 2 5
# ==
#  A entrega atrasou 1 5
# ==
# Horrível!! Produto de péssima qualidade, nada haver com a foto. A saia não é reta igual na foto, fica cheia de pregas. Não compram, só queria o meu dinheiro de volta!!! 5 1
# ==
#  Foi minha primeira compra dessa forma por iso não dá para fazer uma avaliação exata  1 4
# ==
#  Não recebi todo os produto? 5 1
# ==
# Bom Chegou conforme anunciado 1 5
# ==
#  O cartucho está estourado (vazando), já contatei a empresa. Foi-me informado que haverá a troca! 1 5
# ==
#  Não recomendo.  5 1
# ==
#  Mais um vez veio faltando o item Kit Flor Artificial Orquídea Chuva De Ouro 10 Unidades 	Vendido e entregue por targaryen 	Qtd 1
#  4 1
# ==
#  Nada demais, entregou o pedido no prazo. Sem nada à mais. 1 4
# ==
#  Recebi o produto cheio de defeitos. Já solicitei devolução do dinheiro, estou aguardando retorno 5 1
# ==
#  Também ligar para o cliente quando for preciso 1 5
# ==
# Recomendo Apesar do produto não ser exatamente turbo, carrega o celular de boas
# quanto a entrega e o prazo, tudo perfeito 1 4
# ==
# Panos de copa  2 5
# ==
#  Até agora não recebi 4 1
# ==
# Exelente o melhor banho que tomei foi com esta ducha, excelente 1 5
# ==
#  Linda cortina, ótimo material. 1 5
# ==
# Quero o dinheiro de volta Só chegou uma licença com o selo da Microsoft e a outra veio impressa na nota fiscal, o que achei muito estranho. Além disso a licença não funciona. 5 1
# ==
# Recebido Produto de qualidade! 2 5
# ==
# Ótima cinta Material muito bom. Design robusto . Cumpre o que promete. 1 5
# ==
#  Recomendo o produto muito bom. Pensei q seria mais grande mais goste igual.  1 5
# ==
#  Não posso opinar. Endereço errado, ainda não recebi. 1 5
# ==
#  Mosquitos frustrados pela boa qualidade do Mosquitero. Nunca mais acordar cantando. 1 4
# ==
#  O produto é bonito, material bom e bem acabado. 1 4
# ==
#  não esta sendo eficiente, me deram um prazo de entrega e ate agora nada  5 1
# ==
#  Recomendo para qualquer pessoa fazer a compra nesta loja pois a entrega ocorreu antes do prazo. 1 4
# ==
#  Nunca me decepcionou!!  1 5
# ==
#  Entregaram o produto certo e no prazo, só deixaram a desejar um pouco na comunicação com o site das lannister, pois no site não mostrava as atualizações de rastreio, fora isso a entrega foi feita. 1 5
# ==
#  Produto não foi entregue. 5 1
# ==
# Perfeito Produto corresponde ao anunciado. Ótimo custo beneficio. 1 5
# ==
#  Segundo cancelamento do mesmo item no site lannister.com. Fiz duas compras em lojas diferentes, as duas canceladas, faz quase 3 meses que estou aguardando o produto. E demora demais para avisar. 5 1
# ==
# RAZOÁVEL O PEDIDO FOI PARCELADO EM 10 VEZES MAS O CARTÃO baratheon PASSOU EM 3 VEZES. POR ISSO NÃO COMPRARIA NOVAMENTE  1 5
# ==
#  Produto como anunciado. Entrega rápida. 1 5
# ==
#  O produto não era bem o que eu pensei.... Mas foi entregue de acordo com o combinado... Até mais cedo do que a data prevista  1 4
# ==
# o produto chegou bem emba produto chegou bem embalado, infelizmente, comprei o produto errado. vou fazer contato com o vendedor para tentar trocar o produto. 1 5
# ==
# Produto bom Apesar de ter sido entregue no prazo levou dez dias para emitirem a nota fiscal sendo que já recebi vários produtos que comprei na lannister em três dias melhorem isso aí! 1 4
# ==
#  rapido na entrega e produto conforme o anunciado 1 5
# ==
#  Está apontando como entregue no rastreamento, mas o produto não foi recebido. Ainda estou no aguardo. 4 1
# ==
#  Parece que vamos ter que trocar o produto. A boia veio furada. 2 5
# ==
#  Recebi o produto antes do prazo previsto, e tudo em ordem, porém, após 5 min. de utilização, o massageador parou de funcionar... já solicitei o cancelamento da compra e estou aguardando a retirada. 1 4
# ==
#  LOJA BEM RECOMEDADA 2 5
# ==
#  adorei o produto 2 5
# ==
#  Ainda não recebi o produto, além de ser um prazo mega extenso, não cumpriram com o combinado!
#
# E aii??? 5 1
# ==
#  Pelo preço pensei que o produto fosse melhor. Atende as necessidades. 1 4
# ==
#  o relógio é bonito, porém não é para o dia a dia, por ser de material bem inferior, mas pelo preço está ok 1 4
# ==
#  Gostei da qualidade da carteira porém achei pequena. targaryen é confiável.  1 5
# ==
# Super recomendo Produto conforme o anuncio, envio rapido e embalagem otima. 1 5
# ==
#  Ótimo site para comprar muito confiável 4 1
# ==
#  Veio separado do outro produto. 1 4
# ==
# Muito Bom! Cumpriu o que se esperava. 1 5
# ==
#  Adorei o produto, só que no site v é colocado como vermelho mas na verdade a cor e vinho  2 5
# ==
# não recomendo pelo valor pago a qualidade foi bem inferior, eu não compraria novamente 5 1
# ==
#  Faltou identificar a voltagem na embalagem, e na nota fiscal, é necessário abrir a embalagem pra ver que existe um selinho, com a voltagem colada no motor.  1 4
# ==
# A boneca A boneca não é igual a imagem que está no site, por isso fiquei bem desapontado, pois sempre que comprei algumas coisas por esse site eram bem atendidas  5 1
# ==
#  Responsável  1 5
# ==
#  tudo ok so atrasou a entrega
#  1 5
# ==
#  Tudo conforme anunciado, produto ótimo, venda OK!
#  1 5
# ==
#  Entrega tranquila; produto conforme anunciado, muito lindas as toalhas 1 5
# ==
# não recomendo comprei uma cortina de 3x2,80. me enviaram duas cortinas, sendo cada uma de 1,50x2,80. PALHAÇADAAAAAAAAAAAAAAAAAAAAAAAAA.
#
#
# se eu quisesse uma cortina de 1,50 eu comprava de 1x50, e não de 3 metros 4 1
# ==
# Entregue  Produto entregue, avaliado e instalado! No prazo e perfeito. 1 4
# ==
#  A parte superior do produto foi mal feita, não encaixa corretamente e está folgada. 4 1
# ==
#  Satisfação 100% 1 5
# ==
# produto devolvido  o meu produto foi devolvido do correio quando fui pegar e até o momento não recebi 2 5
# ==
#  Minha mercadoria chegou antes do prazo e é exelente  5 1
# ==
#  Recebi o produto porém não é original,e como é um produto pra ingerir não quero colocar a minha saúde em risco.  4 1
# ==
# Produto de qualidade   2 5
# ==
# Estou configurando nest  2 5
# ==
#  boa noite, recebi o tecnico instalou dia 28/05/18 e hoje dia 31/05/18 a placa queimou, e agora o que que eu faço? o produto foi instalado seguindo toda a orientação técnica recomendada. 1 5
# ==
#  Parabéns a loja por ter entregue o produto anunciado e antes do prazo previsto!! Produto muito bom conforme o esperado!! 1 5
# ==
# Muito bom Sempre gostei de comprar neste site, devido as divergências com o cartão stark que cobra a anuidade muito caro eu canselei o meu cartão stark e fui comprar nos concorrentes.  1 5
# ==
#  Produto não entregue 5 1
# ==
#  produtos de qualidade 2 5
# ==
#  Não gostei do produto, vou solicitar troca 1 5
# ==
#  Não recebi o produto 2 5
# ==
#  Nao recebi... e nem recebi justificatica porqie tá demorando 5 1
# ==
#  Livro magnífico e entrega no prazo  1 5
# ==
#  Só foi entregue um dos produtos 5 1
# ==
#  Está dentro do que eu esperava. 1 4
# ==
#  Estou de 16 semanas e da pra ouvir direitinho o coraçãozinho! Vale a pena!  2 5
# ==
#  produto recebido e funcionando, muito bom. 2 5
# ==
#  Chegou tudo de acordo com o anuncio e antes do prazo especificado pelo site. 1 5
# ==
#  Comprei 3 luminárias, só recebi 2. Já abrir chamado e não tive resposta. 4 1
# ==
# SUPER RECOMENDO macio, regulável, muito confortavel 2 5
# ==
#  Produto entregue conforme anunciado  1 5
# ==
#  a qualidade do produto é melhor do que eu esperava. 1 4
# ==
#  Tudo certo conforme anunciado, recomendo. 1 5
# ==
#  CONFORME ANUNCIO 1 4
# ==
#  O cheiro do produto e muito forte! Mas pelo preço não tenho do que reclamar! 5 1
# ==
#  não foi entregue 5 1
# ==
#  Nada mais a avaliar, pois ainda estou testando o produto! 1 4
# ==
#  Produto idêntico ao anunciado. Não recebi no prazo pq o caminhão foi roubado.  1 5
# ==
#  Considerando o site stark nunca tive problema algum e recomendo ao meus amigos porém está empresa que está atendendo com a venda do produto deixou a desejar com o prazo de entrega... Será q chega? 4 1
# ==
#  Comprei no Quiosque da Loja Americana, acompanhei o pedido até receber, 100 % confiável. 1 5
# ==
#  Minha experiência com essa compra fou muito boa! Além de ter bom preço, a entrega foi muito rápida. 1 5
# ==
#  Demorou quase 15 dias pra falar que não tinha o produto no estoque... muita falta de responsabilidade da empresa. 5 1
# ==
#  Navalha muito bonita!! 2 5
# ==
#  lindo , produto igual ao anunciado  1 5
# ==
#  Adorei vou pedir mais 1 5
# ==
#  Parabéns para toda equipe. 5 2
# ==
# recomendo O material é bom, o problema é que a bolsa não fecha, não possui zíper, é como uma sacola. Isso me deixou insatisfeita, pois na foto não dá pra perceber e não há informação ou foto interna sobre isso. 1 4
# ==
#  Feito de material bem resistente, e tamanho conforme o anunciado. Mercadoria entregue dentro do prazo previsto. 1 5
# ==
#  Produto entregue conforme anunciado, tudo ok. 1 5
# ==
# Nunca mais! Decepção total por conta de uma empresa que sempre comprei e indicava a meus amigos, sempre disse que a lannister era super fiel aos seus prazos. Comprei um produto com um prazo que quase 30 dias par 5 1
# ==
#  produto muito bom assino embaixo aprovado nota 10 1 5
# ==
#  O produto é maravilhoso mas pela quantidade não vale a pena 5 1
# ==
#  Loja excelente. Cumpre o que anuncia e a promessa contida no anúncio. 1 5
# ==
#  Eu só recebi um lustre e comprei dois anota veio dois e só recebi um  5 1
# ==
# Produto errado  O produto veio diferente do que eu pedi paguei frete é tive de ir aos Correios em uma agência muito distante de casa  4 1
# ==
# Ainda não chegou Estou esperando há quase um mês, uma falta de respeito ao consumidor 5 1
# ==
#  Não recebi o produto na quantidade adquirida, pois somente uma embalagem (pote) invés de duas. 5 1
# ==
#  Melhor do que esperava 1 5
# ==
#  A loja é excelente, más o produto foi ruim. Pelicula de plástico. Não indico o produto para ninguém. Não vale apena. 2 5
# ==
#  Produto não entregue 5 1
# ==
#  Ainda não recebi meu produto, kit maternidade, o que preciso receber com urgêncica, pois estou para dar a luz a qualquer momento. Sempre compro pelo baratheon e nunca antes tive problemas com o prazo. 1 5
# ==
#  Escrevi o endereço errado, mas tá chegando. 1 4
# ==
# Não recebi até agora  Tudo pago, produto e frete e não chegou nada  4 1
# ==
# Produto conforme anuncio Recomendo 1 4
# ==
#  Ainda não recebi o meu produto o prazo de entrega era até 23/03 e até agora não chegou. 4 1
# ==
#  Não cancelaram meu pedido na data certa, agora tenho que levar no correio 4 1
# ==
# É muito fraco.  4 1
# ==
#  Comprei dois produtos no mesmo dia, sexta-feira de black friday, no início de dezembro. O jogo de panelas tramontina chegou dentro do prazo, que era até o dia 11-12, mas a pipoqueira ainda não chegou. 5 1
# ==
# Muito ruim  Meu produto constar que foi entregue mais não chegou nada na minha casa e hoje de manhã eu liguei na central da lannister pra saber o que aconteceu e atendente? mim informou pra ey esperar até terça  4 1
# ==
#  O produto veio em ótimas condições e antes do prazo estipulado, porém o único mal entendido é que no anuncio ele era Branco mas, veio na cor preta.  1 5
# ==
#  O Produto veio avariado. A caixa do mesmo muito amassada, com alguns rasgos e cheia de fita adesiva. E o produto veio sem uma das rodas. Já mandei vários e-mails para a stark e não tive retorno... 5 1
# ==
#  Quando o produto chegou percebi que não era combativel com windows 10. Estou ha 4 dias tentando falar com o SAC para saber o procedimento para trocar por um outro do proprio site da lannister. 1 4
# ==
#  Meu produto não chegou  5 1
# ==
#  Este é apenas uma parte do pedido.
# Falta enviar o HD 1 5
# ==
# Produto não foi entregue Produto não foi entregue 5 1
# ==
# gostei dessa loja. Muito boa essa loja, entregue o produto no prazo, 100% confiável.  1 5
# ==
#  lannister deveria cancelar essa parceria pois a empresa targaryen é um embuste , é fraudulenta , agiu de má fé . Essa empresa denigre a imagem das lannister.com ... Estou no aguardo do meu reembolso 5 1
# ==
#  por ser um jogo bordado, esperava um material melhor. mas no geral gostei. 1 4
# ==
#  Adoro a lannister! 1 5
# ==
# Atenção!  Coloquei que não foi entregue por que eu que tive q ir buscar. Eles não entregam na minha casa... E outra uma semana de uso o fone já está dando problemas! 4 1
# ==
#  O produto não foi entregue. Nem se quer chegou em casa.  4 1
# ==
#  Aparelho não funciona direito  4 1
# ==
#  O produto demorou muito pra chegar.  2 5
# ==
# Bom prodito O travesseiro tem excelente qualidade 1 5
# ==
#  Gosteeeeiiiiiiiii 1 5
# ==
# Não tem manual de uso   4 1
# ==
#  DEMOROU 1 POUCO ...MAS CHEGOU CERTO....OBG 2 5
# ==
#  Produto de boa qualidade. É o que eu esperava.  1 5
# ==
#  Foi o que esperava 1 5
# ==
#  aaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaaa 1 4
# ==
#  Tudo dentro do esperado 5 1
# ==
#  ja e a segunda vez que compro o mesmo produto do mesmo fornecedor e estou bem satisfeito. 1 5
# ==
# Ótima aparência  1 5
# ==
#  Gostei...protege mesmo o notebook. Além de caber caderno.  1 5
# ==
# Caixa transportada parc c  1 5
# ==
# Produto com defeito Não consigo falar com vocês. 1 5
# ==
# Comecei a usar agora Ta em fase de teste 1 5
# ==
#  sit confiavel 1 5
# ==
# Bom Material muito bom
#  1 4
# ==
#  Produto bom relativo ao preço 1 5
# ==
#  recebi mas ainda não instalei. Veio conforme imaginei . lindo, espero que funcione perfeitamente. 2 5
# ==
#  Não era bem o que eu esperava
#  5 1
# ==
#  O prazo para meu produto chegar era até o dia 10/04/2018 e até agora não recebi. 4 1
# ==
#  Infelizmente, encontramos na internet, lojas que para poderem vender, dizem que tem o produto pedido. Ao finalizar o pedido, o cliente fica à mercê do prazo de entrega que, nem sempre é cumprido. 5 2
# ==
#  Leve e confortável. 2 5
# ==
#  Atraso na entrega sem dar satisfação ao cliente, que com certeza escolheu o produto com cuidado e com as melhores expectativas. Falta de consideração. 4 1
# ==
#  O produto é otimo, mas a lannister deixa muito a desejar. O produto chegou dentro do prazo, mas era 16 dias de prazo, muito tempo de espera e tambem uns dos produtos veio ERRADO. 5 1
# ==
#  Só acho que se fosse entregue através de transportadora seria mais rápido 1 5
# ==
#  Veio para crianças maior de 3 meses e meu bb tem um mês  1 5
# ==
#  Uma das melhores compras que já fiz 2 5
# ==
#  GOSTARIA DE RECEBER 1 COPIA DA NF, DEVE TER EXTRAVIADO
#  1 5
# ==
#  Não é muito agradável pois faz muito barulho qndo nos mexemos na cama,parece q tem um plástico no colchão sem contar q soa não gostei na imagem parece q é tecido qndo chega vê q é plástico. 1 5
# ==
#  Já comprei várias vezes e ainda vou comprar... 1 4
# ==
#  Gostaria de saber o que aconteceu 1 4
# ==
#  Veio até com o selo de importação  2 5
# ==
#  ja comentei anteriormente 1 4
# ==
# ELM OBDII Recomendadíssimo este produto. Atendimento nota 10. Entrega antes do prazo. Vou comprar mais. 2 5
# ==
#  Chegou como esperado, nada a reclamar. Produto de qualidade e bem acondicionado. 1 5
# ==
# Excelente Peço desculpas pela avaliação anterior, onde infomeiuque ainda não havia recebido o produto, na verdade ele estava na portaria do meu prédio. 1 5
# ==
#  Entregaram bem antes do prazo dois dias úteis após a compra. Recomendo. 1 5
# ==
#  ESTOU GOSTANDO DE FAZER COMPRAS NESSA LOJA!  1 4
# ==
#  Estou satisfeita por essa entrega,mas muito chateada pela segunda entrega q ate o momento nao recebi em minha residencia.
# Recebi e-mail de imprevisto nessa entrega.Aguardo resposta. 1 5
# ==
#  O produto foi entregue na casa de um vizinho que eu não tenho contato, como entregam um produto para uma pessoa de outra casa?  4 1
# ==
#  Não foi entregue o produto
#  5 1
# ==
# Leitor de DVD   2 5
# ==
#  Cancelei o produto após a compra devido ao prazo de entrega ser 19 dias e chegar após o feriado de carnaval quando iria utiliza-lo 4 1
# ==
#  SUPER RECOMENDO 5 1
# ==
#  A única coisa que achei que tem que ser melhorada é a comunicação, deixei vários emails e não responderam nenhum, porque tinha dado um problema na entrega, fiquei muito preocupada, mais feliz chegou!! 1 4
# ==
# Bom produto Excelente microfone, acaba sendo um pouco desconfortável se usar durante muito tempo, mas no geral é bom. 2 5
# ==
#  O produto foi entregue antes do prazo combinado, muito Bom!. só tenho uma reclamação, me mandaram o manual de montagem do produto diferente do qual eu recebi  2 5
# ==
#  Amei a Loja e o produto, pois eles aumentaram minha expectativa enviando um recado escrito de próprio punho e alguns brindes que com certeza me agradaram e que comprarei novamente. 2 5
# ==
#  Empresa Confiável 1 4
# ==
# Prazo longo e atraso A loja pediu quase 1 mês para entregar e ainda atrasou a entrega do produto.
# E estamos sem receber o produto. . . 5 2
# ==
#  Loja coloca prazo extremamente extenso para entrega de produtos e nem assim consegue cumpri-los.  5 1
# ==
#  Não veio o produto certo 4 1
# ==
#  Apenas ainda não provei o produto para checar se tudo funcionando  2 5
# ==
#  Conforme esperado 1 5
# ==
# Boa noite bom produto  Boa noite estou com dificuldade de arrumar o RELÓGIO da pulseira e nem conectar o bluetooth  2 5
# ==
#  Recomendo a loja, porém sempre tem algum ponto à melhorar e a sugestão é p/ logística, pois a compra foi efetuada dia 16/03 e até o momento não foi entregue, ou seja, quase 1 mês e ainda não recebi. 5 2
# ==
#  Adorei a mercadoria com certeza vou comprar mais. 1 5
# ==
#  Era oque eu esperava  1 5
# ==
#  Comparei uma banheira e não recebi no prazo combinado tenho pressa pois meu neto está pra nascer antes de eu fazer a compra eu me certifiquei que iriam me entregar na data certa mais não recebi 4 1
# ==
#  Primeira vez que compro e gostei muito desde do acompanhamento do produto até a entrega .
# Muito bom 1 4
# ==
#  Há muito tempo compro no baratheon e, até hoje, só tenho elagios. 1 5
# ==
# FUNCIONA FUNCIONA BEM TE SOMENTE UMA ESCOVA 1 5
# ==
#  Produto não chegou na data. 5 1
# ==
#  Entregue antes do prazo e material de boa qualidade... recomendo 1 5
# ==
#  Chegou no prazo e conforme anunciado! 1 4
# ==
# péssima  Um absurdo!Sempre comprei no site das lannister...nunca tive problema,mais essa última compra está fazendo vergonha...apesar de dar um prazo enorme para entrega q foi quase dois meses ainda não chega 4 1
# ==
#  O produto não foi entregue! 5 1
# ==
#  Não recebi meu produto dentro do prazo e o atendimento foi péssimo 4 1
# ==
#  Produto bom vou usar depois dou uma avaliaçao melhor... 1 4
# ==
#  Fui informado que o produto chegaria até o dia 18/03/2018, mas até agora não recebi. 4 1
# ==
#  O prazo de entrega é longo, o valor do frete é muito alto em relação a Porto Velho - RO  1 4
# ==
#  ADOREI A CARTEIRA...ESTOU ESPERANDO O OUTRO PRODUTO..( capa carteira para celular)
#
# OBRIGADA 1 5
# ==
#  Não foi entregue o relógio. 5 1
# ==
#  Não gostei de não poder acompanhar a entrega do produto porque no aplicativo apenas constava produto em transporte e previsão de entrega, porém não encontrei o código de rastreamento dos correios.  1 4
# ==
#  Recebi o produto antes do prazo, ok. Porem o produto veio cheio de avarias, arranhões em várias partes, descascado, e a parte de encaixar não encaixava, enfim, acabei de solicitar a devolução. 5 1
# ==
#  Produto pago, mas não houve entrega até agora. 4 1
# ==
# Entrega Gostei muito da minha balança digital
#  2 5
# ==
# Recomendo Entrega no prazo e conforme anunciado! 1 5
# ==
#  Ótimo.
# Deram 19 dias úteis e me entregaram em 3 1 5
# ==
# Relogio Euro produto entregue conforme o anuncio 1 5
# ==
#  Só realizei a compra pq chegava antes do Natal e até agora nada de chegar.  1 5
# ==
#  O produto na venda era uma imagem clara e bonita, quando chegou e totalmente preto e quase não da para ver a imagem . 5 2
# ==
# ...
# ==
#  Entrega rápida e relogio muito bonito. Porém eu comprei com os números na cor azul e veio na verde, mas como também gostei, nao fiz a troca. O relógio nao fica muito grande no braço! 1 4
# ==
# Super recomendo Todas as vezes que compro nessa loja, o produto chega no prazo e sou informada por e-mail do deslocamento do produto até o endereço final.
#  1 5
# ==
#  Eu compro muito pela net. E este não recebi
#  4 1
# ==
#  Nao entregou e nem derao satisfacao do motivo......... 5 1
# ==
#  Entregue pelos Correios antes do prazo! Tenho mais um produto a receber pela transportadora dentro do prazo mais demorado não chegou ainda!
#  2 5
# ==
#  não recomendo 5 1
# ==
#  ........................ 1 5
# ==
#  apesar de eu ter um produto pendente desde dezembro de 2017 ,essa outra compra chegou até antes do prazo .o numero do outro pedido é 02-658094288 se possivel checa pra mim por favor. 1 5
# ==
#  o pente é ótimo! Nem se compara ao de plástico! 1 4
# ==
#  gostei continue assin 1 5
# ==
#  Adorei muito  1 5
# ==
#  Achei que demorou muito pra chegar pq alguns produtos que comprei depois chegaram antes.  2 5
# ==
#  Correto com o que eu esperava 1 4
# ==
# recomendado tudo perfeito, mas com relação a pelicula ,não esta conforme o anuncio pois a pelicula não serviu,caso haja condiçoes de enviarem a pelicula certa ou seja LG Q 6 PLUS ,desde ja agradeço 1 4
# ==
#  Ainda não recebi o produto adquirido e não houve nenhuma comunicação sobre o atraso. 5 1
# ==
#  Idêntico ao anuncio, muito lindo  1 5
# ==
#  Entregue antes do prazo.... material muito boa  1 5
# ==
# produto não entregue meu produto não foi entregue, querem que eu retire no correio que é do outro lado da cidade, eu paguei para entregar na minha casa. 4 1
# ==
# Imagem da imagem falsa  Olá não gostei desse produto
# Não fiquei satisfeita
# Na imagem é uma imagem bem viva
# Chegou a imagem apagada
# E não é tecido mas plástico
# Não fiquei satisfeita  1 5
# ==
#  otima agora vou querer LG55 4K 1 5
# ==
#  Gostei do material e a entrega foi até adiantada . 1 5
# ==
# Excelente amei, material excelente
# Embora esteja uma pendencia com as lojas Americana
# Não é porque houve um Deslize que vou dizer que é ruim
#  2 5
# ==
#  É a primeira vez que um produto não chega no prazo 5 2
# ==
#  Até ligaram pra mim para confirmar. Excelente 1 5
# ==
# acusação de recebimento  acuso positivamente o recebimento do produto. 1 4
# ==
# Recomendo Produto de acordo com o anunciado. Entrega dentro do prazo. Aparenta ser bom, com o tempo vou descobrir. 1 4
# ==
#  Ainda não utilizei o produto, mas a entrega foi dentro do prazo. então, na verdade, essa avaliação não é do produto 1 4
# ==
#  Ainda não usei. 4 1
# ==
#  O produto anunciado era café e recebi preto, porém eu queria a preta mesmo. 1 5
# ==
#  O produto anunciado não pertence ao EP 450 não está conectando no rádio. 1 4
# ==
#  A entrega foi dentro do prazo, bem embalada e a empresa comunicou todos os passos da compra e entrega do produto 1 5
# ==
#  Falta atualizar o status do produto com mais precisao pois o status do produto estava com uma data tão distante e sem novidades na entrega que eu já estava com vontade de cancelar o pedido. 1 4
# ==
#  Embora tenha havido atraso na entrega, fui avisado antes de vencer o prazo. Muito obrigado.  1 5
# ==
#  O frete é caro e ainda se quiser tem q buscar no correio.Muito ruim.Ainda quer elogios,odiei. 4 1
# ==
#  Ótimo produto,atendeu bem as minhas necessidades,apesar de ter chegado 5 dias após o prazo estipulado no ato da compra,valeu a pena pela qualidade e bom preço. 1 4
# ==
#  Amo comprar na Amazon, compro muito pela internet pra mim, pra outros e a stark nunca, mas nunca me decepciona mesmo!  1 5
# ==
# Recomendo a todos Produto conforme anunciado, é entregue dentro do prazo recomendo a todos a loja e o produto! 1 5
# ==
#  A previsão seria para o dia 5, mas temos que dar um desconto por causa dos correios. 1 5
# ==
#  Cadeiras ótimas. Excelente material. 1 5
# ==
# o produto parece ser bom, o led do produto não acende 1 4
# ==
#  RECOMENDO A LOJA, MAS O PERFUME NÃO. TEM CHEIRO DE NADA!  5 1
# ==
#  Dentro do esperado. Bom material. 1 5
# ==
#  Já fiz a solicitação de devolver a compra e já está quase vencendo as 48 horas solicitadas. Se meu problemas não for solucionado dentro do prazo estipulado tomarei as medidas cabíveis junto ao procon. 5 1
# ==
#  O produto ainda n chegou e eu queria saber se ainda tem chances dele chegar. Caso não gostaria de exigir o reembolso. 4 1
# ==
#  Muito bom a entrega, recebemos em 3dias após faturamento. 1 5
# ==
#   não consegui retira o produto está no correios , no me ta errado , por favo entre em contato comigo (61991198226) 5 1
# ==
#  O esperado pelo valor  1 5
# ==
#  Já fiz várias compras. excelentes produtos e preços bastante acessíveis. 2 5
# ==
# Ok Tamanho meio pequeno e a grama sintética tem pouca qualidade, esperava algo um pouco mais resistente. Mas pelo valor compensou. Conforme a imagem  1 4
# ==
#  Atraso na entrega. 1 4
# ==
#  Capa muito boa, atendeu as necessidades, o único problema foi a falta de informação sobre o paradeiro da entrega. Só foi informado que os correios estavam com dificuldade. 1 4
# ==
#  Recebí dentro do prazo!
# Kit original! 1 5
# ==
#  Produto chegou dentro do prazo, lannister nunca decepciona! 2 5
# ==
#  entrega super rápida, produto conforme anunciado. 1 5
# ==
# Pote de vidro com tampa  Ótimo produto, eu recomendo!  2 5
# ==
#  Chegou bem antes do prazo e Happy ficou lindo de Batman. 1 5
# ==
#  Adoramos muito  1 5
# ==
#  A nota fiscal veio lacrada com durex e rasgou toda na hora de retirar. 1 4
# ==
#  Embora todo o processo tenho corrido bem, o produto veio com defeito. Farei a devolução no gatilho que não obstrui a passagem da água. 1 5
# ==
#  Tudo perfeito, produto veio corretamente e sem atrasos 1 5
# ==
#  Infelizmente não recebi o produto. Fui contactada pela loja faz quase 10 dias e nem assim consegui receber a cadeira. Que chato.. 5 1
# ==
#  Muito bom atendimento. Exatamente o que foi anunciado  1 5
# ==
#  Eu comprei na cor azul e veio rosa. 1 5
# ==
#  Recebe o produto antes do prazo. Amei a entrega. O produto ainda não usei, mas depois que usar de eu não gostar volto pra falar. Mas já comprei esse botox em outras lojas e minhas clientes amam. 1 5
# ==
# Não recomendo O produto chegou sem problemas. Mas ele não é o que esta sendo dito. Sua tabela nutricional é enganosa e o produto adulterado! Não é whey protein isolado! 5 1
# ==
#  Ainda não usei o produto mas chegou completo e em 2 dias! Muito rápido! 2 5
# ==
#  MERCADORIA ENTREGUE  1 4
# ==
#  Chegou antes do prazo, é como anunciado, ótimo produto. 1 5
# ==
# Foi uma boa compra A mochila é muito boa por fora, entretanto dentro, no bolso de separação interna, já rasgou no segundo dia de uso e sem peso em excesso!  1 4
# ==
#  gerou um stress porque recebi um e-mail para eu entrasse em contato com o parceiro e não vocês resolverem dizendo os correios informaram as lojas lannister que o produto não havia chego para entrega 1 4
# ==
#  Pedido cancelado.  1 4
# ==
#  Estante chegou muito bem embalada e no prazo. Mercadoria conforme anuncio.
# Gostei 1 5
# ==
#  td otimo,porem ainda nao abri o produto e nem fiz uso dele. 1 5
# ==
#  Ótimo material  1 5
# ==
#  Chegou muuuuito antes do prazo.  2 5
# ==
# Boa Avaliação O produto é bom, bonito tem bom acabamento 1 5
# ==
#  Eu já fui cliente há muitos anos atrás, e agora comprei novamente. Confiabilidade e pontualidade são as marcas da empresa 1 5
# ==
#  Material de boa qualidade 1 5
# ==
#  comprei 02 unidades (teria que receber 20 panos de prato barrado), mas recebi somente 01 unidade (recebi 10 panos de prato barrado.) Dando é que paguei o valor de 95,80. 1 4
# ==
#  Tudo ok. Só que eu preciso fazer a troca deste produto qual procedimento. 1 5
# ==
# Péssima entrega Recebi apenas o copo térmico personalizado, mas a placa decorativa não. 5 1
# ==
#  Só o whey chegou atrasado mas o motivo do atraso foi dos correios  1 5
# ==
#  Toalha de péssima qualidade, prefiro as dá marca casa e conforto. 4 1
# ==
# não recomendo fiz uma compra de duas garrafas super caras, recebi apenas uma. e o principal o filtro de quase 600,00 reais não vieram estar no meu e-mail como entregue. so tento recebido uma garrafa. gostaria resp. 5 1
# ==
#  Na verdade não estou falando mal da loja em si ,mas sim do produto que adquiri que é de péssima qualidade 5 2
# ==
#  Indico otimos pneus!👏 1 5
# ==
#  Sempre compro nas lojas lannister, dessa vez demoroi a chegar por causa da greve dos correios, fora isso e bem rápida à entrega!  1 4
# ==
# ***** o produto era exatamente o que eu precisasa 5 1
# ==
#  Nada a declarar 1 4
# ==
#  gostei muito dos produtos .. pretendo comprar outros . 2 5
# ==
#  Produto de péssima qualidade e acabamento.  4 1
# ==
# Ótimo produto Acabamento e material de qualidade. Coube meu notebook de 15,6' sem problemas. Além disso, foi entregue muito rápido. 2 5
# ==
# Excelente Somente o Frete que acho ainda muito caro 2 5
# ==
# Tinta para canet Ótimo  1 5
# ==
#  Foi feito o pedido do produto,mas houve problemas com a targaryen e o mesmo foi cancelado 1 4
# ==
#  Comprei pq confio no site do stark 1 5
# ==
#  Muito bom nao fica froxo onde conecta firme
#  1 5
# ==
#  A maquina é linda, fácil de usar, forte, silenciosa, manual bem explicado e chegou na metade do prazo de entrega. 1 5
# ==
#  a espera do reembolso. ou cancelarei o pagamento 1 4
# ==
#  Gostei do produto. 4 1
# ==
#  recomento super diferente e lindo 2 5
# ==
#  Inox e inox escovado. 1 5
# ==
#  Não posso dizer nada Ainda  1 4
# ==
#  Entrega super ágil, bem antes do prazo final. Porém recebi um produto diferente do anunciado, mas de boa qualidade e que satisfez minha necessidade.  1 4
# ==
# Funciona O controle não é específico da marca da TV, é um controle universal que você encontra em qualquer lugar. 1 4
# ==
#  de qualidade 1 5
# ==
#  Estas empresas que mandam os produtos desmontados, mandam com o numero "exato" de peças, o problema quando falta... faltou uma porca 1 4
# ==
# Recusa O produto chegou avariado e recusei a entrega 5 2
# ==
# Pequeno' Só achei muito pequeno e a grama MUITO ruim 1 5
# ==
#  Produto entregue conforme anunciado. 1 5
# ==
#  Nao veio a luva mandaram um relogio feio no lugar sem me consultar antes 1 4
# ==
# Satisfeito Ótimo Produto tudo de acordo com o anuncio e a entrega foi muito rápida estou muito satisfeito 1 4
# ==
# Não recomendado Apesar de estar no prazo de entrega o produto demorou muito para chegar, fiz o pedido do mesmo produto em um concorrente do stark que entregou bem antes. 5 1
# ==
#  O ÚNICO PONTO NEGATIVO FOI A ENTREGA, PAGUEI FRETE E TIVE QUE RETIRAR NA AGÊNCIA DOS CORREIOS, POIS INFORMARAM Q A NUMERAÇÃO DO ENDEREÇO É IRREGULAR O QUE É UMA VERDADEIRA MENTIRA 1 4
# ==
#  Chegou absurdamente rápido.  1 5
# ==
#  Valeu apena comprar. 1 5
# ==
# Tive que ir buscar  A transportadora informou que eu estava ausente em casa, sendo que passo o dia todo em casa não teve nem opção de ligar para reclamar .. 4 1
# ==
# SUPER RECOMENDO produto conforme o anunciado. Fiquei satisfeita. 1 5
# ==
#  Tirando a cor errada o resto estava perfeito
# O que não foi bom é que vou ter que devolver o produto por não ser a cor que foi solicitada, todo o transtorno de devolver e esperar retornar. 1 4
# ==
#  EU DE COMPRAR NA baratheon, AINDA NAO TIVE QUE RECLAMAR ESPERO QUE CONTINUA ASSIM OBRIGADA.  1 5
# ==
#  foi a melhor compra que eu fiz.
# o jogo é lindissimo. 2 5
# ==
#  Produto igual o anunciado e chegou bem antes do prazo indicado. 1 5
# ==
#  aDOREI PRODUTO. mUITO PRATICO! 2 5
# ==
#  comprei vei certinho esse pedido mas umas banquetas que comprei antes desse pedido agora não chegou falaram que entregou mas eu n recebi comprei antes desse pedido e nao chegou 1 5
# ==
#  Faz mais de 30 dias que realizei uma compra e não recebi o produto.
# O status do site só informa que se tem problema na entrega, quando tento ligar na central também não tenho sucesso. 5 1
# ==
#  Paguei um frente caro e despois tive que carregar peso do correio até em casa. Não gostei! 4 1
# ==
#  Pedi uma bateria para um notebook e até agora nada de chegar pedi a um tempo já  4 1
# ==
#  recebi no prazo, ainda nao pode instalar para conferir o funcionamento. 2 5
# ==
#  Paguei pelo frete, deveria receber o produto em minha casa , não vou busvar nos correios, eu trabalho 4 1
# ==
#  Fiquei sem informações de rastreamento em tempo real. Chegou o produto é o rastreamento não indicava isso.  1 4
# ==
#  Goste e comprei mais duas pra organizar meus Vinhos. 1 5
# ==
#  olá , meu produto foi entregue , muito antes do prazo . minha queixa é apenas pelo produto não ter sido aquilo que eu esperava.  1 4
# ==
#  Tem como me envia o meu produto novamente  1 5
# ==
#  VENDEDOR CONFIÁVEL 1 5
# ==
#  Gostei desse modelo. Tem a vantagem de usar pilhas ao invés de bateria interna, o que facilita a troca quando necessário. As baterias internas custam 1/3 do valor do aparelho. 1 5
# ==
#  Gostei muito, a entrega foi pontual e material veio certo. 1 5
# ==
# problema com o relógio O relógio foi entregue sem nota fiscal nem manual 4 1
# ==
# nao recomendo mau atendimento. ate agora nao resolveram meu problema.  4 1
# ==
# Entrega O produto em si não testei, não instalei ainda na esteira. No entanto a rapidez na entrega foi eficiente.
# Parece resistente, porém somente com o uso prolongado é que permitirá uma melhor avaliação. 1 4
# ==
#  Apenas uma coisa: Durante o transporte, não recebi o código de rastreio, então não sabia onde o produto estava. Fora isso, tudo perfeito!  1 5
# ==
#  Não me entregaram o produto até agora, não cancelei o pedido e em contato com as Lojas lannister me disseram que não entregaram pois não tem em estoques e isso ja faz quase um ano que comprei.  5 1
# ==
#  Tô contente. Gostei do produto.  1 4
# ==
#  Produto muito bom e com material resistente. 1 5
# ==
#  Cheiro ruim e muito forte, frete mais caro que o produto. 5 2
# ==
#  Não comprei esse produto e nem e o numero do meu cartão. Aguardo retorno 1 4
# ==
#  Produto que não atende ao que se propõe e além disso com especificações propostas diferente do entregue 5 1
# ==
#  Material foi entregue no prazo  1 5
# ==
#  Os 4 rolos chegaram juntos e 12 dias antes do prazo, numa compra anterior targaryen entregou 3 rolos em datas diferentes. O adesivo é de boa qualidade mas a colocação exige muita habilidade e paciência!  1 5
# ==
#  Cumpriu e respeitou o consumidor. 1 5
# ==
#  Um dos produtos chegou com atraso, mas fora isso sempre que peço chega tudo direitinho. 1 5
# ==
# Entrega Segue eu fiz o cancelamento de compra desse produto, solicito que não sera mais necessário, pois foi eu que não soube mexer com o relógio, esta funcionando perfeitamente tudo certo obrigado. 1 5
# ==
#  Comprei uma Balança de cozinha,mas me entregaram uma caixa contendo uma película de celular. Preciso que verifiquem pra mim o que houve. Resolvam isso logo por favor. muito obrigada! 1 4
# ==
#  O relógio veio com defeito, pulseira quebrada, estou tentando fazer a troca, até o momento sem sucesso 5 1
# ==
#  Recebi o produto e gostei da qualidade 2 5
# ==
#  Entrega no prazo e produto de qualidade. Satisfeito com o material. 1 5
# ==
# recomendo sim o produto apresentou defeito, mas assistência esta me dando o devido suporte. 1 4
# ==
#  O produto não funciona e não é o que está descrito no site para compra. 5 1
# ==
#  Produto original 1 5
# ==
#  Ainda não recebi a blusa na entrega  2 5
# ==
#  Produto veio bem embalado e no prazo, ainda não instalei.. 2 5
# ==
#  Apesar da demora em receber, o produto chegou e é bom!! 2 5
# ==
#  É por isso que compro com vcs! Nota 10 1 5
# ==
#  Loja melhor só na Irineu, vc não sabe nem eu 1 5
# ==
#  meu produto não chegou 5 1
# ==
# Produto com Defeito O produto adquirido não pode ser utilizado, o mesmo apresentou problemas de montagem, Aguardando a troca do produto..... 5 2
# ==
#  O produto chegou faltando e em péssimas condições. 5 1
# ==
#  sim recebi na cor preta ....queria na cor vermelha...queria o que aconteceu...obriagodo b oa n oite  1 4
# ==
#  produto de acordo com anuncio. 1 5
# ==
#  Atrasou apenas um dia pra entrega de todas as peças. Fiquei satisfeita com o produto e com o atendimento ao cliente da loja. 1 4
# ==
# Muito bom Nada tenho contra a loja. E recomendo sem sombra de dúvida. Recusei o recebimento do produto porque estava em desacordo com a utilização. Obrigada. 1 4
# ==
#  Muito satisfeito com o andamento da compra e com o produto. 2 5
# ==
#  Muito bom, produto conforme anunciado, entrega antes do prazo. 1 5
# ==
#  Gostei muito.
# É a segunda vez que compro o mesmo produto. 1 5
# ==

# %%
len(badly_classified_reviews)/len(df)
# Out:
# 0.08887252038302304

# %% [markdown]
# Out of all the reviews in the dataset, roughly 9% of the reviews were classified with an error of more than 3.
#
# Some of the reviews were classified incorrectly due to the inaccuracy of our classifier. For example:
#
# Review | English | Predicted | Actual
# --- | --- | --- | ---
# Conforme o esperado | As expected | 1 | 5
# Produto original e lacrado. Nota 10 | Original and sealed product. Grade 10 | 2 | 5
#
# While other reviews were classified incorrectly because the user put in a score that did not match the text
#
# Review | English | Predicted | Actual
# --- | --- | --- | ---
# muito obrigado | Thank you so much | 5 | 1
# O PRODUTO FOI ENTREGUE EM LOCAL ERRADO. ENTRETANTO CONSEGUI RECEBER, AGUARDO A ENTRAGA DA MÁQUINA DE LAVAR NO ENDEREÇO CORRETO: RUA GENERAL IVAN RAPOSO, 44 AP 101- BARRA DA TIJUCA, RIO DE JANEIRO | THE PRODUCT HAS BEEN DELIVERED IN A WRONG PLACE. HOWEVER I GOT TO RECEIVE, WAIT FOR THE WASHING MACHINE TO BE ENTERED AT THE CORRECT ADDRESS: RUA GENERAL IVAN RAPOSO, 44 AP 101- BARRA DA TIJUCA, RIO DE JANEIRO | 1 | 4
